# %% [markdown]
# ### to run this code, you need to have standalone EMBOSS (getorf), BLAST, and HMMER installed

# %%
import subprocess
import os
from glob import glob
from Bio import SearchIO
from Bio import SeqIO 
from Bio.Blast import NCBIXML

# %% [markdown]
# ## load and adjust all paths

# %%
outdir = "/home/majnusova/all/projects/plv/data/eustig_orfs/" #adjust
genomes = glob("/home/majnusova/all/projects/plv/data/genomes_test/*.fasta")
hmm_model = "/home/majnusova/all/projects/bilabrum/data/hmm/Packiging_ATPase.hmm" #adjust
output_directory = "/home/majnusova/all/projects/plv/data/eustigs_hmmout/" #adjust
orf_files = glob("/home/majnusova/all/projects/plv/data/eustig_orfs/*_orfs.fa") #adjust: list of orf databases
blastables_outdir = "/home/majnusova/all/projects/plv/data/blastables/"
scaffolds_dir = "/home/majnusova/all/projects/plv/data/eve_outscaffolds/"
blastables_outdir = "/home/majnusova/all/projects/plv/data/blastables/"

# %% [markdown]
# ### Extract ORFs from genomes

# %%
def run_getorf(genome, orf_file):
    command = ["getorf", "-sequence", genome, "-outseq", orf_file, "-table", "0", "-minsize", "360", "-find", "1"] #adjust (120 aa, START to STOP, standard gen. code)
    subprocess.run(command, check=True)

outdir = "/home/majnusova/all/projects/plv/data/eustig_orfs/" #adjust
genomes = glob("/home/majnusova/all/projects/plv/data/genomes_test/*.fasta") #adjust - this is just a test dataset

for genome in genomes:
    orf_file = f"{outdir}{genome.split('/')[-1].replace('.fasta', '_orfs.fa')}"
    run_getorf(genome, orf_file)
# Out:
# Find and extract open reading frames (ORFs)
# Find and extract open reading frames (ORFs)
# Find and extract open reading frames (ORFs)

# %% [markdown]
# ### hmmsearch with HMM against those extracted ORFs -> hmmout

# %%
# running hhmmsearch against multiple databases at once and saving the resulting files using the .hmmout suffix
def run_hmmsearch(orf_file, hmm_model, output_file):
    command = ["hmmsearch", "-o", output_file, hmm_model, orf_file]
    subprocess.run(command, check=True)

hmm_model = "/home/majnusova/all/projects/bilabrum/data/hmm/Packiging_ATPase.hmm" #adjust
output_directory = "/home/majnusova/all/projects/plv/data/eustigs_hmmout/" #adjust
orf_files = glob("/home/majnusova/all/projects/plv/data/eustig_orfs/*_orfs.fa") #adjust: list of orf databases


# iterate over the list of database files and run hmmsearch 
for orf_file in orf_files:
    output_file = f"{output_directory}{orf_file.split('/')[-1].replace('_orfs.fa', '_atp.hmmout')}" 
    run_hmmsearch(orf_file, hmm_model, output_file) #needs to be nested inside the loop!

# %% [markdown]
# ### saving IDs of ALL homologs above inclusion threshold found by HMMER and name of the assembly they were found in
# ### genome_scaffold_ids - genome: ids

# %% [raw]
# # saving IDs of sequences above the inclustion treshold into ids_list
# ids_list_orfs = []
# for file in glob("/home/majnusova/all/projects/plv/data/eustigs_hmmout/*_atp.hmmout"):
#     hmmer_file = SearchIO.read(file, "hmmer3-text")
#     for record in hmmer_file:
#         if record.is_included:
#             ids_list_orfs.append(record.id)
# len(ids_list_orfs)

# %%
# names of viral orfs and the genome they originate from
genome_scaffold_orfs = {}

for file in glob("/home/majnusova/all/projects/plv/data/eustigs_hmmout/*_atp.hmmout"):
    genome_name = os.path.basename(file).split('_atp.hmmout')[0] # getting the real names of the genomes; os.path.basename(file) extracts the base name from the file's full path.
    if genome_name not in genome_scaffold_orfs:
        genome_scaffold_orfs[genome_name] = []

    hmmer_file = SearchIO.read(file, "hmmer3-text")
    
    for record in hmmer_file:
        if record.is_included:
            scaffold_id = record.id  # scaffold ID - removing _orf
            genome_scaffold_orfs[genome_name].append(scaffold_id)
            
total_viral_orfs = sum(len(i)for i in genome_scaffold_orfs.values())
total_viral_orfs
# Out:
# 280

# %%
genome_scaffold_orfs
# Out:
# {'Chic10_scaffolds': ['NODE_5080_length_5696_cov_26.6876_1',
#   'NODE_381_length_27838_cov_14.2215_25',
#   'NODE_7293_length_4272_cov_22.9291_3',
#   'NODE_5397_length_5445_cov_37.4879_2',
#   'NODE_6066_length_4954_cov_14.3046_4',
#   'NODE_847_length_17049_cov_12.9829_3',
#   'NODE_7343_length_4249_cov_22.2454_2',
#   'NODE_19673_length_1550_cov_34.6107_1',
#   'NODE_1409_length_12728_cov_15.5927_2',
#   'NODE_1574_length_11923_cov_14.5027_1',
#   'NODE_711_length_18631_cov_14.7806_4',
#   'NODE_15445_length_2031_cov_23.9084_2',
#   'NODE_15112_length_2083_cov_16.6144_1',
#   'NODE_12470_length_2567_cov_17.4088_2',
#   'NODE_34064_length_837_cov_18.9655_1',
#   'NODE_4057_length_6629_cov_27.157_1',
#   'NODE_865_length_16875_cov_12.6059_4',
#   'NODE_869_length_16855_cov_12.4798_4',
#   'NODE_6477_length_4696_cov_21.0899_1',
#   'NODE_17368_length_1781_cov_15.3621_1',
#   'NODE_18418_length_1671_cov_21.013_1',
#   'NODE_352_length_29307_cov_12.7034_4',
#   'NODE_31105_length_924_cov_16.8895_1',
#   'NODE_4114_length_6570_cov_18.8181_3',
#   'NODE_64132_length_412_cov_37.521_1',
#   'NODE_21363_length_1410_cov_17.5911_2',
#   'NODE_729_length_18418_cov_17.5178_2',
#   'NODE_2989_length_8109_cov_18.7196_1',
#   'NODE_19459_length_1568_cov_14.5763_2',
#   'NODE_5193_length_5598_cov_18.435_1',
#   'NODE_1700_length_11441_cov_11.3554_2',
#   'NODE_23099_length_1285_cov_30.4293_1',
#   'NODE_5175_length_5619_cov_15.8523_3',
#   'NODE_1497_length_12259_cov_17.1079_5',
#   'NODE_45_length_194274_cov_4.45832_227',
#   'NODE_726_length_18432_cov_13.3793_4',
#   'NODE_2472_length_9153_cov_15.0004_3',
#   'NODE_1914_length_10584_cov_13.0671_6',
#   'NODE_27232_length_1069_cov_21.7475_1',
#   'NODE_16_length_371769_cov_13.539_405',
#   'NODE_1_length_1589435_cov_13.0886_269',
#   'NODE_10_length_626405_cov_4.34645_166',
#   'NODE_70_length_144148_cov_190.155_76',
#   'NODE_7137_length_4338_cov_10.9433_1',
#   'NODE_498_length_23434_cov_17.1238_3',
#   'NODE_33_length_241831_cov_197.129_26',
#   'NODE_89_length_113149_cov_3.22244_46',
#   'NODE_33_length_241831_cov_197.129_40',
#   'NODE_146_length_60639_cov_3.37158_5',
#   'NODE_95_length_100189_cov_309.803_24',
#   'NODE_122_length_74444_cov_387.187_15',
#   'NODE_381_length_27838_cov_14.2215_15',
#   'NODE_55_length_165510_cov_190.906_69',
#   'NODE_58_length_162532_cov_4.15186_9',
#   'NODE_30947_length_2131_cov_44.927459_1',
#   'NODE_14086_length_5828_cov_114.282560_5',
#   'NODE_6253_length_15760_cov_50.012179_2',
#   'NODE_15254_length_5228_cov_2.298583_6',
#   'NODE_5979_length_16534_cov_39.455794_8',
#   'NODE_1103_length_61346_cov_37.814180_76',
#   'NODE_5256_length_18861_cov_43.559891_30',
#   'NODE_26439_length_2586_cov_73.009167_2',
#   'NODE_19752_length_3746_cov_115.179340_1',
#   'NODE_6042_length_16357_cov_74.447850_1',
#   'NODE_320_length_153881_cov_39.008816_191',
#   'NODE_5631_length_17651_cov_35.077843_19',
#   'NODE_5268_length_18834_cov_37.274020_5',
#   'NODE_3853_length_25035_cov_37.882483_16',
#   'NODE_4047_length_24047_cov_37.496871_5',
#   'NODE_10355_length_8667_cov_4.009197_4',
#   'NODE_5666_length_17540_cov_39.164046_3',
#   'NODE_33887_length_1914_cov_61.497550_1',
#   'NODE_55499_length_1145_cov_1.835206_1',
#   'NODE_8905_length_10501_cov_38.608020_2',
#   'NODE_1923_length_42336_cov_37.970586_26',
#   'NODE_5165_length_19175_cov_36.990494_16',
#   'NODE_5439_length_18295_cov_39.951393_8',
#   'NODE_17515_length_4365_cov_1.628498_2',
#   'NODE_5524_length_18020_cov_60.640138_4',
#   'NODE_520_length_104572_cov_40.248251_16',
#   'NODE_19882_length_3715_cov_117.832600_1',
#   'NODE_6056_length_16321_cov_54.183514_5',
#   'NODE_8489_length_11111_cov_39.627696_2',
#   'NODE_13274_length_6293_cov_67.948359_7',
#   'NODE_867_length_72283_cov_40.422873_20',
#   'NODE_5210_length_19024_cov_41.343752_8',
#   'NODE_5279_length_18785_cov_37.128715_17',
#   'NODE_5291_length_18737_cov_38.505953_15',
#   'NODE_19711_length_3755_cov_177.878738_3',
#   'NODE_65277_length_988_cov_80.268935_1',
#   'NODE_5948_length_16621_cov_56.953276_9',
#   'NODE_5185_length_19113_cov_51.963228_8',
#   'NODE_40175_length_1581_cov_138.559840_1',
#   'NODE_11128_length_7875_cov_48.125160_3',
#   'NODE_4244_length_22945_cov_43.032228_19',
#   'NODE_16638_length_4668_cov_96.428229_2',
#   'NODE_82285_length_807_cov_44.949315_1',
#   'NODE_5813_length_16982_cov_41.874260_2',
#   'NODE_22990_length_3089_cov_142.543493_3',
#   'NODE_4874_length_20116_cov_37.345077_6',
#   'NODE_5339_length_18576_cov_37.831018_13',
#   'NODE_9574_length_9580_cov_44.215616_1',
#   'NODE_61658_length_1040_cov_1143.640706_1',
#   'NODE_829_length_74096_cov_65.354085_7',
#   'NODE_11665_length_7441_cov_57.376697_2',
#   'NODE_5143_length_19243_cov_42.491339_7',
#   'NODE_10655_length_8337_cov_41.157627_6',
#   'NODE_8934_length_10461_cov_43.715716_10',
#   'NODE_866_length_72325_cov_37.472691_52',
#   'NODE_6781_length_14418_cov_37.653650_17',
#   'NODE_52373_length_1210_cov_1.902913_1',
#   'NODE_6984_length_13947_cov_38.879380_3',
#   'NODE_17516_length_4364_cov_81.868206_1',
#   'NODE_5215_length_19019_cov_37.828236_20',
#   'NODE_1465_length_50215_cov_45.222007_18',
#   'NODE_3667_length_26145_cov_48.502378_19',
#   'NODE_8746_length_10716_cov_29.281041_9',
#   'NODE_134624_length_517_cov_187.613636_1',
#   'NODE_2774_length_32621_cov_36.854996_23',
#   'NODE_46036_length_1373_cov_634.591821_2',
#   'NODE_6872_length_14173_cov_71.224177_3',
#   'NODE_11077_length_7924_cov_13.114948_4',
#   'NODE_6502_length_15105_cov_32.811019_6',
#   'NODE_8508_length_11095_cov_11.485025_4',
#   'NODE_70317_length_926_cov_1.542992_1',
#   'NODE_4742_length_20636_cov_41.178511_13',
#   'NODE_12796_length_6585_cov_96.566994_4',
#   'NODE_145468_length_482_cov_1.654321_1',
#   'NODE_187922_length_374_cov_50.824916_1',
#   'NODE_6984_length_13947_cov_38.879380_2',
#   'NODE_163194_length_431_cov_109.146893_1',
#   'NODE_3601_length_26483_cov_35.616072_22',
#   'NODE_19693_length_3759_cov_2.326453_4',
#   'NODE_8_length_920040_cov_17.887887_833',
#   'NODE_160797_length_438_cov_1.152355_1',
#   'NODE_171_length_238445_cov_572.810663_248',
#   'NODE_311_length_156469_cov_32.611502_212',
#   'NODE_25832_length_2666_cov_10.276555_3',
#   'NODE_15_length_759953_cov_292.559295_262',
#   'NODE_197_length_219627_cov_52.866117_27',
#   'NODE_152_length_259012_cov_32.238044_218',
#   'NODE_9657_length_9486_cov_41.815390_5',
#   'NODE_38_length_520036_cov_47.857456_203',
#   'NODE_27_length_600914_cov_14.349319_580',
#   'NODE_179_length_230196_cov_11.871036_47',
#   'NODE_132_length_285120_cov_137.485885_215',
#   'NODE_2364_length_36824_cov_1984.494571_9',
#   'NODE_254_length_184797_cov_7.251294_105',
#   'NODE_377_length_136897_cov_6.550351_176',
#   'NODE_1634_length_47073_cov_31.715572_51',
#   'NODE_3763_length_25504_cov_3.576867_6',
#   'NODE_113_length_322384_cov_46.569383_318',
#   'NODE_4384_length_22242_cov_940.677600_3',
#   'NODE_398_length_128959_cov_17.006463_86',
#   'NODE_619_length_90376_cov_5.509109_46',
#   'NODE_330_length_150702_cov_302.813457_253',
#   'NODE_14578_length_5562_cov_2.695716_2',
#   'NODE_155_length_252422_cov_128.823373_158',
#   'NODE_395_length_129935_cov_617.085062_224',
#   'NODE_153_length_255781_cov_13.970744_62',
#   'NODE_182_length_228583_cov_79.382664_47',
#   'NODE_48_length_497299_cov_6.449061_169',
#   'NODE_6496_length_15111_cov_1016.212452_3',
#   'NODE_6701_length_14585_cov_3.780604_1',
#   'NODE_117_length_315731_cov_6.054322_363',
#   'NODE_53743_length_1180_cov_2.126020_1',
#   'NODE_8688_length_10798_cov_2.900009_6',
#   'NODE_15287_length_5216_cov_4.023545_6',
#   'NODE_4297_length_22640_cov_6.481496_2',
#   'NODE_4572_length_21411_cov_2.919518_3',
#   'NODE_24607_length_2830_cov_2.762078_2',
#   'NODE_9289_length_9944_cov_2.221851_18',
#   'NODE_965_length_66675_cov_6.078110_86',
#   'NODE_20805_length_3501_cov_2.607477_2',
#   'NODE_115_length_316723_cov_17.494170_17',
#   'NODE_1_length_1214521_cov_6.930895_1878',
#   'NODE_65_length_422212_cov_6.412126_503',
#   'NODE_531_length_103019_cov_5.844194_147',
#   'NODE_13626_length_6093_cov_7.413564_4',
#   'NODE_19755_length_3746_cov_3.259471_4',
#   'NODE_5023_length_19616_cov_937.917959_5',
#   'NODE_8232_length_11555_cov_2.784893_21',
#   'NODE_173_length_232916_cov_265.596429_426',
#   'NODE_38137_length_1675_cov_2.742178_1',
#   'NODE_3018_length_30458_cov_4.146045_60',
#   'NODE_11733_length_7373_cov_2.742462_15',
#   'NODE_50189_length_1261_cov_1.277872_2',
#   'NODE_35_length_543908_cov_16.984931_392',
#   'NODE_32_length_556671_cov_424.843629_80',
#   'NODE_145_length_273263_cov_31.304994_495',
#   'NODE_38562_length_1656_cov_2.459785_1',
#   'NODE_741_length_79403_cov_185.477208_114',
#   'NODE_21626_length_3339_cov_2.077866_2',
#   'NODE_9207_length_10065_cov_2.478274_4',
#   'NODE_217_length_208486_cov_6.840141_154',
#   'NODE_208_length_212550_cov_43.804855_251',
#   'NODE_15194_length_5265_cov_2.682151_1',
#   'NODE_34_length_549459_cov_93.351604_851',
#   'NODE_9_length_911479_cov_90.897796_472',
#   'NODE_12484_length_6796_cov_1290.573002_1',
#   'NODE_6433_length_15242_cov_3.264820_13',
#   'NODE_10_length_908469_cov_12.406104_30',
#   'NODE_39_length_517803_cov_7.286389_789',
#   'NODE_53948_length_1176_cov_1.693358_1',
#   'NODE_2119_length_39630_cov_2.885243_25',
#   'NODE_1064_length_63035_cov_6.873725_79',
#   'NODE_28709_length_2337_cov_3.107522_2',
#   'NODE_62_length_444389_cov_18.131093_102',
#   'NODE_80950_length_820_cov_1.360700_2',
#   'NODE_135_length_281329_cov_13.280030_127',
#   'NODE_176_length_232184_cov_8.619279_91',
#   'NODE_23925_length_2930_cov_2.353663_3',
#   'NODE_1_length_1214521_cov_6.930895_63',
#   'NODE_20309_length_3613_cov_2.466629_6',
#   'NODE_2425_length_36271_cov_3.294192_30',
#   'NODE_157_length_250643_cov_11.185995_221']}

# %%
# creating a dict of lists (genomes: ids)
genome_scaffold_ids = {}

for file in glob("/home/majnusova/all/projects/plv/data/eustigs_hmmout/*_atp.hmmout"):
    genome_name = os.path.basename(file).split('_atp.hmmout')[0] # getting the real names of the genomes; os.path.basename(file) extracts the base name from the file's full path.
    if genome_name not in genome_scaffold_ids:
        genome_scaffold_ids[genome_name] = []

    hmmer_file = SearchIO.read(file, "hmmer3-text")
    
    for record in hmmer_file:
        if record.is_included:
            scaffold_id = record.id.rsplit("_", 1)[0] # scaffold ID - removing _orf
            genome_scaffold_ids[genome_name].append(scaffold_id)

# %%
genome_scaffold_ids
# Out:
# {'Chic10_scaffolds': ['NODE_5080_length_5696_cov_26.6876',
#   'NODE_381_length_27838_cov_14.2215',
#   'NODE_7293_length_4272_cov_22.9291',
#   'NODE_5397_length_5445_cov_37.4879',
#   'NODE_6066_length_4954_cov_14.3046',
#   'NODE_847_length_17049_cov_12.9829',
#   'NODE_7343_length_4249_cov_22.2454',
#   'NODE_19673_length_1550_cov_34.6107',
#   'NODE_1409_length_12728_cov_15.5927',
#   'NODE_1574_length_11923_cov_14.5027',
#   'NODE_711_length_18631_cov_14.7806',
#   'NODE_15445_length_2031_cov_23.9084',
#   'NODE_15112_length_2083_cov_16.6144',
#   'NODE_12470_length_2567_cov_17.4088',
#   'NODE_34064_length_837_cov_18.9655',
#   'NODE_4057_length_6629_cov_27.157',
#   'NODE_865_length_16875_cov_12.6059',
#   'NODE_869_length_16855_cov_12.4798',
#   'NODE_6477_length_4696_cov_21.0899',
#   'NODE_17368_length_1781_cov_15.3621',
#   'NODE_18418_length_1671_cov_21.013',
#   'NODE_352_length_29307_cov_12.7034',
#   'NODE_31105_length_924_cov_16.8895',
#   'NODE_4114_length_6570_cov_18.8181',
#   'NODE_64132_length_412_cov_37.521',
#   'NODE_21363_length_1410_cov_17.5911',
#   'NODE_729_length_18418_cov_17.5178',
#   'NODE_2989_length_8109_cov_18.7196',
#   'NODE_19459_length_1568_cov_14.5763',
#   'NODE_5193_length_5598_cov_18.435',
#   'NODE_1700_length_11441_cov_11.3554',
#   'NODE_23099_length_1285_cov_30.4293',
#   'NODE_5175_length_5619_cov_15.8523',
#   'NODE_1497_length_12259_cov_17.1079',
#   'NODE_45_length_194274_cov_4.45832',
#   'NODE_726_length_18432_cov_13.3793',
#   'NODE_2472_length_9153_cov_15.0004',
#   'NODE_1914_length_10584_cov_13.0671',
#   'NODE_27232_length_1069_cov_21.7475',
#   'NODE_16_length_371769_cov_13.539',
#   'NODE_1_length_1589435_cov_13.0886',
#   'NODE_10_length_626405_cov_4.34645',
#   'NODE_70_length_144148_cov_190.155',
#   'NODE_7137_length_4338_cov_10.9433',
#   'NODE_498_length_23434_cov_17.1238',
#   'NODE_33_length_241831_cov_197.129',
#   'NODE_89_length_113149_cov_3.22244',
#   'NODE_33_length_241831_cov_197.129',
#   'NODE_146_length_60639_cov_3.37158',
#   'NODE_95_length_100189_cov_309.803',
#   'NODE_122_length_74444_cov_387.187',
#   'NODE_381_length_27838_cov_14.2215',
#   'NODE_55_length_165510_cov_190.906',
#   'NODE_58_length_162532_cov_4.15186',
#   'NODE_98_length_98422_cov_62.5464',
#   'NODE_43_length_199121_cov_7.50572',
#   'NODE_2_length_969053_cov_7.62238',
#   'NODE_37_length_230641_cov_4.40646',
#   'NODE_4001_length_6695_cov_39.1587',
#   'NODE_10658_length_3024_cov_17.2284',
#   'NODE_11_length_515168_cov_3.2278',
#   'NODE_63_length_153037_cov_4.46219',
#   'NODE_1003_length_15534_cov_74.2099',
#   'NODE_244_length_37664_cov_11.8205',
#   'NODE_104_length_85964_cov_12.9853',
#   'NODE_66_length_150458_cov_3.12336',
#   'NODE_3_length_955702_cov_6.81221',
#   'NODE_28_length_282822_cov_9.9159',
#   'NODE_13_length_427009_cov_190.15',
#   'NODE_94_length_101213_cov_13.992',
#   'NODE_2_length_969053_cov_7.62238',
#   'NODE_95_length_100189_cov_309.803',
#   'NODE_3_length_955702_cov_6.81221',
#   'NODE_312_length_31651_cov_4.15834',
#   'NODE_2_length_969053_cov_7.62238',
#   'NODE_11781_length_2744_cov_19.5329',
#   'NODE_34592_length_823_cov_18.1107',
#   'NODE_34_length_241557_cov_7.5501',
#   'NODE_6241_length_4835_cov_7.08054',
#   'NODE_9_length_666414_cov_4.15495',
#   'NODE_26_length_312622_cov_7.43917',
#   'NODE_1_length_1589435_cov_13.0886'],
#  'Vischeria_C74_genome_v1': ['Vischeria_C74_contig_15',
#   'Vischeria_C74_contig_12',
#   'Vischeria_C74_contig_9',
#   'Vischeria_C74_contig_46',
#   'Vischeria_C74_contig_4',
#   'Vischeria_C74_contig_13',
#   'Vischeria_C74_contig_27',
#   'Vischeria_C74_contig_13',
#   'Vischeria_C74_contig_33',
#   'Vischeria_C74_contig_10',
#   'Vischeria_C74_contig_10',
#   'Vischeria_C74_contig_19',
#   'Vischeria_C74_contig_2',
#   'Vischeria_C74_contig_4',
#   'Vischeria_C74_contig_33',
#   'Vischeria_C74_contig_16',
#   'Vischeria_C74_contig_25',
#   'Vischeria_C74_contig_9',
#   'Vischeria_C74_contig_13',
#   'Vischeria_C74_contig_9',
#   'Vischeria_C74_contig_8',
#   'Vischeria_C74_contig_3',
#   'Vischeria_C74_contig_18',
#   'Vischeria_C74_contig_9',
#   'Vischeria_C74_contig_16',
#   'Vischeria_C74_contig_12',
#   'Vischeria_C74_contig_16'],
#  'Characiopsis_New_scaffolds': ['NODE_541_length_101851_cov_46.471309',
#   'NODE_8926_length_10478_cov_112.808095',
#   'NODE_6781_length_14418_cov_37.653650',
#   'NODE_7519_length_12830_cov_74.394025',
#   'NODE_6613_length_14812_cov_55.852596',
#   'NODE_22338_length_3203_cov_73.093410',
#   'NODE_55_length_463973_cov_37.984469',
#   'NODE_28174_length_2388_cov_130.530074',
#   'NODE_7863_length_12198_cov_39.876825',
#   'NODE_30947_length_2131_cov_44.927459',
#   'NODE_14086_length_5828_cov_114.282560',
#   'NODE_6253_length_15760_cov_50.012179',
#   'NODE_15254_length_5228_cov_2.298583',
#   'NODE_5979_length_16534_cov_39.455794',
#   'NODE_1103_length_61346_cov_37.814180',
#   'NODE_5256_length_18861_cov_43.559891',
#   'NODE_26439_length_2586_cov_73.009167',
#   'NODE_19752_length_3746_cov_115.179340',
#   'NODE_6042_length_16357_cov_74.447850',
#   'NODE_320_length_153881_cov_39.008816',
#   'NODE_5631_length_17651_cov_35.077843',
#   'NODE_5268_length_18834_cov_37.274020',
#   'NODE_3853_length_25035_cov_37.882483',
#   'NODE_4047_length_24047_cov_37.496871',
#   'NODE_10355_length_8667_cov_4.009197',
#   'NODE_5666_length_17540_cov_39.164046',
#   'NODE_33887_length_1914_cov_61.497550',
#   'NODE_55499_length_1145_cov_1.835206',
#   'NODE_8905_length_10501_cov_38.608020',
#   'NODE_1923_length_42336_cov_37.970586',
#   'NODE_5165_length_19175_cov_36.990494',
#   'NODE_5439_length_18295_cov_39.951393',
#   'NODE_17515_length_4365_cov_1.628498',
#   'NODE_5524_length_18020_cov_60.640138',
#   'NODE_520_length_104572_cov_40.248251',
#   'NODE_19882_length_3715_cov_117.832600',
#   'NODE_6056_length_16321_cov_54.183514',
#   'NODE_8489_length_11111_cov_39.627696',
#   'NODE_13274_length_6293_cov_67.948359',
#   'NODE_867_length_72283_cov_40.422873',
#   'NODE_5210_length_19024_cov_41.343752',
#   'NODE_5279_length_18785_cov_37.128715',
#   'NODE_5291_length_18737_cov_38.505953',
#   'NODE_19711_length_3755_cov_177.878738',
#   'NODE_65277_length_988_cov_80.268935',
#   'NODE_5948_length_16621_cov_56.953276',
#   'NODE_5185_length_19113_cov_51.963228',
#   'NODE_40175_length_1581_cov_138.559840',
#   'NODE_11128_length_7875_cov_48.125160',
#   'NODE_4244_length_22945_cov_43.032228',
#   'NODE_16638_length_4668_cov_96.428229',
#   'NODE_82285_length_807_cov_44.949315',
#   'NODE_5813_length_16982_cov_41.874260',
#   'NODE_22990_length_3089_cov_142.543493',
#   'NODE_4874_length_20116_cov_37.345077',
#   'NODE_5339_length_18576_cov_37.831018',
#   'NODE_9574_length_9580_cov_44.215616',
#   'NODE_61658_length_1040_cov_1143.640706',
#   'NODE_829_length_74096_cov_65.354085',
#   'NODE_11665_length_7441_cov_57.376697',
#   'NODE_5143_length_19243_cov_42.491339',
#   'NODE_10655_length_8337_cov_41.157627',
#   'NODE_8934_length_10461_cov_43.715716',
#   'NODE_866_length_72325_cov_37.472691',
#   'NODE_6781_length_14418_cov_37.653650',
#   'NODE_52373_length_1210_cov_1.902913',
#   'NODE_6984_length_13947_cov_38.879380',
#   'NODE_17516_length_4364_cov_81.868206',
#   'NODE_5215_length_19019_cov_37.828236',
#   'NODE_1465_length_50215_cov_45.222007',
#   'NODE_3667_length_26145_cov_48.502378',
#   'NODE_8746_length_10716_cov_29.281041',
#   'NODE_134624_length_517_cov_187.613636',
#   'NODE_2774_length_32621_cov_36.854996',
#   'NODE_46036_length_1373_cov_634.591821',
#   'NODE_6872_length_14173_cov_71.224177',
#   'NODE_11077_length_7924_cov_13.114948',
#   'NODE_6502_length_15105_cov_32.811019',
#   'NODE_8508_length_11095_cov_11.485025',
#   'NODE_70317_length_926_cov_1.542992',
#   'NODE_4742_length_20636_cov_41.178511',
#   'NODE_12796_length_6585_cov_96.566994',
#   'NODE_145468_length_482_cov_1.654321',
#   'NODE_187922_length_374_cov_50.824916',
#   'NODE_6984_length_13947_cov_38.879380',
#   'NODE_163194_length_431_cov_109.146893',
#   'NODE_3601_length_26483_cov_35.616072',
#   'NODE_19693_length_3759_cov_2.326453',
#   'NODE_8_length_920040_cov_17.887887',
#   'NODE_160797_length_438_cov_1.152355',
#   'NODE_171_length_238445_cov_572.810663',
#   'NODE_311_length_156469_cov_32.611502',
#   'NODE_25832_length_2666_cov_10.276555',
#   'NODE_15_length_759953_cov_292.559295',
#   'NODE_197_length_219627_cov_52.866117',
#   'NODE_152_length_259012_cov_32.238044',
#   'NODE_9657_length_9486_cov_41.815390',
#   'NODE_38_length_520036_cov_47.857456',
#   'NODE_27_length_600914_cov_14.349319',
#   'NODE_179_length_230196_cov_11.871036',
#   'NODE_132_length_285120_cov_137.485885',
#   'NODE_2364_length_36824_cov_1984.494571',
#   'NODE_254_length_184797_cov_7.251294',
#   'NODE_377_length_136897_cov_6.550351',
#   'NODE_1634_length_47073_cov_31.715572',
#   'NODE_3763_length_25504_cov_3.576867',
#   'NODE_113_length_322384_cov_46.569383',
#   'NODE_4384_length_22242_cov_940.677600',
#   'NODE_398_length_128959_cov_17.006463',
#   'NODE_619_length_90376_cov_5.509109',
#   'NODE_330_length_150702_cov_302.813457',
#   'NODE_14578_length_5562_cov_2.695716',
#   'NODE_155_length_252422_cov_128.823373',
#   'NODE_395_length_129935_cov_617.085062',
#   'NODE_153_length_255781_cov_13.970744',
#   'NODE_182_length_228583_cov_79.382664',
#   'NODE_48_length_497299_cov_6.449061',
#   'NODE_6496_length_15111_cov_1016.212452',
#   'NODE_6701_length_14585_cov_3.780604',
#   'NODE_117_length_315731_cov_6.054322',
#   'NODE_53743_length_1180_cov_2.126020',
#   'NODE_8688_length_10798_cov_2.900009',
#   'NODE_15287_length_5216_cov_4.023545',
#   'NODE_4297_length_22640_cov_6.481496',
#   'NODE_4572_length_21411_cov_2.919518',
#   'NODE_24607_length_2830_cov_2.762078',
#   'NODE_9289_length_9944_cov_2.221851',
#   'NODE_965_length_66675_cov_6.078110',
#   'NODE_20805_length_3501_cov_2.607477',
#   'NODE_115_length_316723_cov_17.494170',
#   'NODE_1_length_1214521_cov_6.930895',
#   'NODE_65_length_422212_cov_6.412126',
#   'NODE_531_length_103019_cov_5.844194',
#   'NODE_13626_length_6093_cov_7.413564',
#   'NODE_19755_length_3746_cov_3.259471',
#   'NODE_5023_length_19616_cov_937.917959',
#   'NODE_8232_length_11555_cov_2.784893',
#   'NODE_173_length_232916_cov_265.596429',
#   'NODE_38137_length_1675_cov_2.742178',
#   'NODE_3018_length_30458_cov_4.146045',
#   'NODE_11733_length_7373_cov_2.742462',
#   'NODE_50189_length_1261_cov_1.277872',
#   'NODE_35_length_543908_cov_16.984931',
#   'NODE_32_length_556671_cov_424.843629',
#   'NODE_145_length_273263_cov_31.304994',
#   'NODE_38562_length_1656_cov_2.459785',
#   'NODE_741_length_79403_cov_185.477208',
#   'NODE_21626_length_3339_cov_2.077866',
#   'NODE_9207_length_10065_cov_2.478274',
#   'NODE_217_length_208486_cov_6.840141',
#   'NODE_208_length_212550_cov_43.804855',
#   'NODE_15194_length_5265_cov_2.682151',
#   'NODE_34_length_549459_cov_93.351604',
#   'NODE_9_length_911479_cov_90.897796',
#   'NODE_12484_length_6796_cov_1290.573002',
#   'NODE_6433_length_15242_cov_3.264820',
#   'NODE_10_length_908469_cov_12.406104',
#   'NODE_39_length_517803_cov_7.286389',
#   'NODE_53948_length_1176_cov_1.693358',
#   'NODE_2119_length_39630_cov_2.885243',
#   'NODE_1064_length_63035_cov_6.873725',
#   'NODE_28709_length_2337_cov_3.107522',
#   'NODE_62_length_444389_cov_18.131093',
#   'NODE_80950_length_820_cov_1.360700',
#   'NODE_135_length_281329_cov_13.280030',
#   'NODE_176_length_232184_cov_8.619279',
#   'NODE_23925_length_2930_cov_2.353663',
#   'NODE_1_length_1214521_cov_6.930895',
#   'NODE_20309_length_3613_cov_2.466629',
#   'NODE_2425_length_36271_cov_3.294192',
#   'NODE_157_length_250643_cov_11.185995']}

# %%
total_ids = sum(len(id) for id in genome_scaffold_ids.values())
total_ids
# Out:
# 280

# %% [markdown]
# ### Extracting scaffolds with the viral homologs found by HMMER (ids_list), scaffolds shorter than 18000 nt are discarded

# %% [raw]
# # ids_list contains IDs of ORFs, not scaffolds! this list needs to be modified accordingly
# ids_list_scaffolds = []
# for id in ids_list_orfs:
#     id_modified = id.rsplit('_', 1)[0] # removing the number of orf -> id of the scaffold
#     ids_list_scaffolds.append(id_modified)
# print(ids_list_scaffolds)

# %% [markdown]
# #### ids_list_scaffolds = all viral scaffolds above inclusion threshold (may be shorter than 20000)

# %% [raw]
# print(ids_list_scaffolds)

# %% [markdown]
# ## to be able to extract the scaffolds, blastable databases need to be created first (for genome and orfs)

# %%
def makeblastdb(file_path, db_type, blastables_outdir):
    db_name = f"{blastables_outdir}/{file_path.split('/')[-1].split('.')[0]}"
    command = ["makeblastdb", "-in", file_path, "-dbtype", db_type, "-out", db_name, "-parse_seqids"]
    subprocess.run(command, check=True)

blastables_outdir = "/home/majnusova/all/projects/plv/data/blastables/"


for genome_path in genomes:
    makeblastdb(genome_path, "nucl", blastables_outdir) # misto file_path volame s genome_path

for orf_file_path in orf_files:
    makeblastdb(orf_file_path, "prot", blastables_outdir)
# Out:
# Building a new DB, current time: 02/22/2024 17:09:02
# New DB name:   /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds
# New DB title:  /home/majnusova/all/projects/plv/data/genomes_test/Chic10_scaffolds.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 758531 sequences in 9.7346 seconds.
#
#
#
#
# Building a new DB, current time: 02/22/2024 17:09:14
# New DB name:   /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1
# New DB title:  /home/majnusova/all/projects/plv/data/genomes_test/Vischeria_C74_genome_v1.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 55 sequences in 0.471926 seconds.
#
#
#
#
# Building a new DB, current time: 02/22/2024 17:09:14
# New DB name:   /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds
# New DB title:  /home/majnusova/all/projects/plv/data/genomes_test/Characiopsis_New_scaffolds.fasta
# Sequence type: Nucleotide
# Deleted existing Nucleotide BLAST database named /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 602964 sequences in 10.4393 seconds.

# %% [markdown]
# ### modifying a dictionary for blastdbcmd
# #### genome_scaffold_orfs_descr contains the same IDs as genome_scaffold_ids + description

# %%
# creating a dict of lists (genomes: ids)
# this dict contains also the description - it allows the usage of the -range option of blastdbcmd command
genome_scaffold_orfs_descr = {}

for file in glob("/home/majnusova/all/projects/plv/data/eustigs_hmmout/*_atp.hmmout"):
    genome_name = os.path.basename(file).split('_atp.hmmout')[0] # getting the real names of the genomes; os.path.basename(file) extracts the base name from the file's full path.
    if genome_name not in genome_scaffold_orfs_descr:
        genome_scaffold_orfs_descr[genome_name] = []

    hmmer_file = SearchIO.read(file, "hmmer3-text")
    
    for record in hmmer_file:
        if record.is_included:
            genome_scaffold_orfs_descr[genome_name].append(record.id + ";" + record.description)

# %%
genome_scaffold_orfs_descr
# Out:
# {'Chic10_scaffolds': ['NODE_5080_length_5696_cov_26.6876_1;[649 - 1389] No definition line found',
#   'NODE_381_length_27838_cov_14.2215_25;[7239 - 6505] (REVERSE SENSE) No definition line found',
#   'NODE_7293_length_4272_cov_22.9291_3;[1285 - 551] (REVERSE SENSE) No definition line found',
#   'NODE_5397_length_5445_cov_37.4879_2;[929 - 1711] No definition line found',
#   'NODE_6066_length_4954_cov_14.3046_4;[1701 - 964] (REVERSE SENSE) No definition line found',
#   'NODE_847_length_17049_cov_12.9829_3;[16205 - 15435] (REVERSE SENSE) No definition line found',
#   'NODE_7343_length_4249_cov_22.2454_2;[3283 - 4017] No definition line found',
#   'NODE_19673_length_1550_cov_34.6107_1;[1091 - 348] (REVERSE SENSE) No definition line found',
#   'NODE_1409_length_12728_cov_15.5927_2;[12037 - 11291] (REVERSE SENSE) No definition line found',
#   'NODE_1574_length_11923_cov_14.5027_1;[11636 - 10887] (REVERSE SENSE) No definition line found',
#   'NODE_711_length_18631_cov_14.7806_4;[11717 - 12442] No definition line found',
#   'NODE_15445_length_2031_cov_23.9084_2;[1007 - 1726] No definition line found',
#   'NODE_15112_length_2083_cov_16.6144_1;[1950 - 1225] (REVERSE SENSE) No definition line found',
#   'NODE_12470_length_2567_cov_17.4088_2;[1707 - 988] (REVERSE SENSE) No definition line found',
#   'NODE_34064_length_837_cov_18.9655_1;[812 - 63] (REVERSE SENSE) No definition line found',
#   'NODE_4057_length_6629_cov_27.157_1;[1294 - 2037] No definition line found',
#   'NODE_865_length_16875_cov_12.6059_4;[10150 - 10875] No definition line found',
#   'NODE_869_length_16855_cov_12.4798_4;[10218 - 10943] No definition line found',
#   'NODE_6477_length_4696_cov_21.0899_1;[4559 - 3831] (REVERSE SENSE) No definition line found',
#   'NODE_17368_length_1781_cov_15.3621_1;[1624 - 899] (REVERSE SENSE) No definition line found',
#   'NODE_18418_length_1671_cov_21.013_1;[1609 - 866] (REVERSE SENSE) No definition line found',
#   'NODE_352_length_29307_cov_12.7034_4;[26723 - 27448] No definition line found',
#   'NODE_31105_length_924_cov_16.8895_1;[899 - 156] (REVERSE SENSE) No definition line found',
#   'NODE_4114_length_6570_cov_18.8181_3;[2746 - 1535] (REVERSE SENSE) No definition line found',
#   'NODE_64132_length_412_cov_37.521_1;[396 - 1] (REVERSE SENSE) No definition line found',
#   'NODE_21363_length_1410_cov_17.5911_2;[672 - 1400] No definition line found',
#   'NODE_729_length_18418_cov_17.5178_2;[7335 - 7829] No definition line found',
#   'NODE_2989_length_8109_cov_18.7196_1;[5663 - 4935] (REVERSE SENSE) No definition line found',
#   'NODE_19459_length_1568_cov_14.5763_2;[779 - 279] (REVERSE SENSE) No definition line found',
#   'NODE_5193_length_5598_cov_18.435_1;[5287 - 4856] (REVERSE SENSE) No definition line found',
#   'NODE_1700_length_11441_cov_11.3554_2;[5791 - 6354] No definition line found',
#   'NODE_23099_length_1285_cov_30.4293_1;[692 - 123] (REVERSE SENSE) No definition line found',
#   'NODE_5175_length_5619_cov_15.8523_3;[1733 - 1320] (REVERSE SENSE) No definition line found',
#   'NODE_1497_length_12259_cov_17.1079_5;[9581 - 9129] (REVERSE SENSE) No definition line found',
#   'NODE_45_length_194274_cov_4.45832_227;[163652 - 159156] (REVERSE SENSE) No definition line found',
#   'NODE_726_length_18432_cov_13.3793_4;[11716 - 12114] No definition line found',
#   'NODE_2472_length_9153_cov_15.0004_3;[2642 - 2079] (REVERSE SENSE) No definition line found',
#   'NODE_1914_length_10584_cov_13.0671_6;[3605 - 3114] (REVERSE SENSE) No definition line found',
#   'NODE_27232_length_1069_cov_21.7475_1;[144 - 593] No definition line found',
#   'NODE_16_length_371769_cov_13.539_405;[326743 - 320396] (REVERSE SENSE) No definition line found',
#   'NODE_1_length_1589435_cov_13.0886_269;[285854 - 288172] No definition line found',
#   'NODE_10_length_626405_cov_4.34645_166;[158178 - 159890] No definition line found',
#   'NODE_70_length_144148_cov_190.155_76;[92694 - 91942] (REVERSE SENSE) No definition line found',
#   'NODE_7137_length_4338_cov_10.9433_1;[168 - 2180] No definition line found',
#   'NODE_498_length_23434_cov_17.1238_3;[36 - 5906] No definition line found',
#   'NODE_33_length_241831_cov_197.129_26;[58597 - 60225] No definition line found',
#   'NODE_89_length_113149_cov_3.22244_46;[49617 - 51329] No definition line found',
#   'NODE_33_length_241831_cov_197.129_40;[101037 - 102887] No definition line found',
#   'NODE_146_length_60639_cov_3.37158_5;[3846 - 7100] No definition line found',
#   'NODE_95_length_100189_cov_309.803_24;[64053 - 66236] No definition line found',
#   'NODE_122_length_74444_cov_387.187_15;[31328 - 33130] No definition line found',
#   'NODE_381_length_27838_cov_14.2215_15;[27083 - 27838] No definition line found',
#   'NODE_55_length_165510_cov_190.906_69;[142828 - 140420] (REVERSE SENSE) No definition line found',
#   'NODE_58_length_162532_cov_4.15186_9;[8189 - 10378] No definition line found',
#   'NODE_98_length_98422_cov_62.5464_9;[6061 - 8370] No definition line found',
#   'NODE_43_length_199121_cov_7.50572_77;[174067 - 172961] (REVERSE SENSE) No definition line found',
#   'NODE_2_length_969053_cov_7.62238_389;[806100 - 807518] No definition line found',
#   'NODE_37_length_230641_cov_4.40646_312;[103393 - 101777] (REVERSE SENSE) No definition line found',
#   'NODE_4001_length_6695_cov_39.1587_5;[4560 - 2935] (REVERSE SENSE) No definition line found',
#   'NODE_10658_length_3024_cov_17.2284_1;[408 - 3023] No definition line found',
#   'NODE_11_length_515168_cov_3.2278_362;[395952 - 399899] No definition line found',
#   'NODE_63_length_153037_cov_4.46219_187;[66433 - 64055] (REVERSE SENSE) No definition line found',
#   'NODE_1003_length_15534_cov_74.2099_7;[8061 - 6835] (REVERSE SENSE) No definition line found',
#   'NODE_244_length_37664_cov_11.8205_8;[23139 - 29063] No definition line found',
#   'NODE_104_length_85964_cov_12.9853_33;[28969 - 29709] No definition line found',
#   'NODE_66_length_150458_cov_3.12336_160;[141283 - 137153] (REVERSE SENSE) No definition line found',
#   'NODE_3_length_955702_cov_6.81221_1544;[113486 - 111078] (REVERSE SENSE) No definition line found',
#   'NODE_28_length_282822_cov_9.9159_75;[214691 - 212907] (REVERSE SENSE) No definition line found',
#   'NODE_13_length_427009_cov_190.15_250;[246415 - 245729] (REVERSE SENSE) No definition line found',
#   'NODE_94_length_101213_cov_13.992_136;[64416 - 63409] (REVERSE SENSE) No definition line found',
#   'NODE_2_length_969053_cov_7.62238_719;[199190 - 196305] (REVERSE SENSE) No definition line found',
#   'NODE_95_length_100189_cov_309.803_5;[6813 - 9305] No definition line found',
#   'NODE_3_length_955702_cov_6.81221_1476;[204677 - 202896] (REVERSE SENSE) No definition line found',
#   'NODE_312_length_31651_cov_4.15834_41;[16317 - 14713] (REVERSE SENSE) No definition line found',
#   'NODE_2_length_969053_cov_7.62238_407;[858997 - 859902] No definition line found',
#   'NODE_11781_length_2744_cov_19.5329_3;[2650 - 1610] (REVERSE SENSE) No definition line found',
#   'NODE_34592_length_823_cov_18.1107_1;[621 - 1] (REVERSE SENSE) No definition line found',
#   'NODE_34_length_241557_cov_7.5501_140;[147530 - 146763] (REVERSE SENSE) No definition line found',
#   'NODE_6241_length_4835_cov_7.08054_2;[210 - 4727] No definition line found',
#   'NODE_9_length_666414_cov_4.15495_387;[355568 - 356872] No definition line found',
#   'NODE_26_length_312622_cov_7.43917_96;[166004 - 168613] No definition line found',
#   'NODE_1_length_1589435_cov_13.0886_2530;[459267 - 458296] (REVERSE SENSE) No definition line found'],
#  'Vischeria_C74_genome_v1': ['Vischeria_C74_contig_15_2692;[2672880 - 2672014] (REVERSE SENSE)',
#   'Vischeria_C74_contig_12_1658;[2384933 - 2385625]',
#   'Vischeria_C74_contig_9_1614;[2256662 - 2257357]',
#   'Vischeria_C74_contig_46_72;[53524 - 52880] (REVERSE SENSE)',
#   'Vischeria_C74_contig_4_3954;[3530356 - 3529676] (REVERSE SENSE)',
#   'Vischeria_C74_contig_13_3269;[1746586 - 1745741] (REVERSE SENSE)',
#   'Vischeria_C74_contig_27_2237;[751871 - 751188] (REVERSE SENSE)',
#   'Vischeria_C74_contig_13_2994;[2216398 - 2215736] (REVERSE SENSE)',
#   'Vischeria_C74_contig_33_10;[26047 - 26733]',
#   'Vischeria_C74_contig_10_2202;[3055293 - 3055982]',
#   'Vischeria_C74_contig_10_885;[1014995 - 1015657]',
#   'Vischeria_C74_contig_19_2921;[1680595 - 1679756] (REVERSE SENSE)',
#   'Vischeria_C74_contig_2_5583;[1039137 - 1038475] (REVERSE SENSE)',
#   'Vischeria_C74_contig_4_5302;[1636409 - 1635747] (REVERSE SENSE)',
#   'Vischeria_C74_contig_33_410;[531699 - 532529]',
#   'Vischeria_C74_contig_16_620;[1004574 - 1005317]',
#   'Vischeria_C74_contig_25_151;[181340 - 182083]',
#   'Vischeria_C74_contig_9_1559;[2159533 - 2160231]',
#   'Vischeria_C74_contig_13_1297;[1758671 - 1759168]',
#   'Vischeria_C74_contig_9_1913;[2694157 - 2694567]',
#   'Vischeria_C74_contig_8_4488;[1227782 - 1227372] (REVERSE SENSE)',
#   'Vischeria_C74_contig_3_336;[368929 - 369360]',
#   'Vischeria_C74_contig_18_3432;[1224058 - 1223588] (REVERSE SENSE)',
#   'Vischeria_C74_contig_9_1912;[2693732 - 2694133]',
#   'Vischeria_C74_contig_16_737;[1241926 - 1243743]',
#   'Vischeria_C74_contig_12_1405;[1983837 - 1986902]',
#   'Vischeria_C74_contig_16_3270;[743822 - 736131] (REVERSE SENSE)'],
#  'Characiopsis_New_scaffolds': ['NODE_541_length_101851_cov_46.471309_4;[3784 - 4620] No definition line found',
#   'NODE_8926_length_10478_cov_112.808095_5;[6493 - 5744] (REVERSE SENSE) No definition line found',
#   'NODE_6781_length_14418_cov_37.653650_10;[13431 - 14267] No definition line found',
#   'NODE_7519_length_12830_cov_74.394025_1;[8448 - 9161] No definition line found',
#   'NODE_6613_length_14812_cov_55.852596_1;[2541 - 3245] No definition line found',
#   'NODE_22338_length_3203_cov_73.093410_2;[2513 - 1788] (REVERSE SENSE) No definition line found',
#   'NODE_55_length_463973_cov_37.984469_471;[311228 - 310407] (REVERSE SENSE) No definition line found',
#   'NODE_28174_length_2388_cov_130.530074_3;[1522 - 752] (REVERSE SENSE) No definition line found',
#   'NODE_7863_length_12198_cov_39.876825_7;[9632 - 8793] (REVERSE SENSE) No definition line found',
#   'NODE_30947_length_2131_cov_44.927459_1;[1110 - 2123] No definition line found',
#   'NODE_14086_length_5828_cov_114.282560_5;[1863 - 1114] (REVERSE SENSE) No definition line found',
#   'NODE_6253_length_15760_cov_50.012179_2;[4617 - 5456] No definition line found',
#   'NODE_15254_length_5228_cov_2.298583_6;[2754 - 1975] (REVERSE SENSE) No definition line found',
#   'NODE_5979_length_16534_cov_39.455794_8;[15443 - 14604] (REVERSE SENSE) No definition line found',
#   'NODE_1103_length_61346_cov_37.814180_76;[11888 - 11070] (REVERSE SENSE) No definition line found',
#   'NODE_5256_length_18861_cov_43.559891_30;[5421 - 4591] (REVERSE SENSE) No definition line found',
#   'NODE_26439_length_2586_cov_73.009167_2;[851 - 9] (REVERSE SENSE) No definition line found',
#   'NODE_19752_length_3746_cov_115.179340_1;[1900 - 2727] No definition line found',
#   'NODE_6042_length_16357_cov_74.447850_1;[5482 - 6225] No definition line found',
#   'NODE_320_length_153881_cov_39.008816_191;[115549 - 114746] (REVERSE SENSE) No definition line found',
#   'NODE_5631_length_17651_cov_35.077843_19;[7804 - 6977] (REVERSE SENSE) No definition line found',
#   'NODE_5268_length_18834_cov_37.274020_5;[7896 - 8741] No definition line found',
#   'NODE_3853_length_25035_cov_37.882483_16;[20495 - 21331] No definition line found',
#   'NODE_4047_length_24047_cov_37.496871_5;[5379 - 6053] No definition line found',
#   'NODE_10355_length_8667_cov_4.009197_4;[3845 - 2124] (REVERSE SENSE) No definition line found',
#   'NODE_5666_length_17540_cov_39.164046_3;[2356 - 3015] No definition line found',
#   'NODE_33887_length_1914_cov_61.497550_1;[708 - 1397] No definition line found',
#   'NODE_55499_length_1145_cov_1.835206_1;[260 - 988] No definition line found',
#   'NODE_8905_length_10501_cov_38.608020_2;[942 - 1775] No definition line found',
#   'NODE_1923_length_42336_cov_37.970586_26;[37209 - 36535] (REVERSE SENSE) No definition line found',
#   'NODE_5165_length_19175_cov_36.990494_16;[15536 - 14877] (REVERSE SENSE) No definition line found',
#   'NODE_5439_length_18295_cov_39.951393_8;[10033 - 10770] No definition line found',
#   'NODE_17515_length_4365_cov_1.628498_2;[3309 - 4148] No definition line found',
#   'NODE_5524_length_18020_cov_60.640138_4;[7869 - 8600] No definition line found',
#   'NODE_520_length_104572_cov_40.248251_16;[61130 - 61861] No definition line found',
#   'NODE_19882_length_3715_cov_117.832600_1;[2972 - 3706] No definition line found',
#   'NODE_6056_length_16321_cov_54.183514_5;[7111 - 7842] No definition line found',
#   'NODE_8489_length_11111_cov_39.627696_2;[1759 - 2592] No definition line found',
#   'NODE_13274_length_6293_cov_67.948359_7;[1575 - 883] (REVERSE SENSE) No definition line found',
#   'NODE_867_length_72283_cov_40.422873_20;[37948 - 38646] No definition line found',
#   'NODE_5210_length_19024_cov_41.343752_8;[10133 - 10867] No definition line found',
#   'NODE_5279_length_18785_cov_37.128715_17;[15457 - 16293] No definition line found',
#   'NODE_5291_length_18737_cov_38.505953_15;[15529 - 16362] No definition line found',
#   'NODE_19711_length_3755_cov_177.878738_3;[2735 - 2013] (REVERSE SENSE) No definition line found',
#   'NODE_65277_length_988_cov_80.268935_1;[878 - 189] (REVERSE SENSE) No definition line found',
#   'NODE_5948_length_16621_cov_56.953276_9;[9747 - 9037] (REVERSE SENSE) No definition line found',
#   'NODE_5185_length_19113_cov_51.963228_8;[12695 - 11958] (REVERSE SENSE) No definition line found',
#   'NODE_40175_length_1581_cov_138.559840_1;[157 - 687] No definition line found',
#   'NODE_11128_length_7875_cov_48.125160_3;[3179 - 3907] No definition line found',
#   'NODE_4244_length_22945_cov_43.032228_19;[9278 - 8532] (REVERSE SENSE) No definition line found',
#   'NODE_16638_length_4668_cov_96.428229_2;[1886 - 2602] No definition line found',
#   'NODE_82285_length_807_cov_44.949315_1;[633 - 112] (REVERSE SENSE) No definition line found',
#   'NODE_5813_length_16982_cov_41.874260_2;[12131 - 12868] No definition line found',
#   'NODE_22990_length_3089_cov_142.543493_3;[1250 - 531] (REVERSE SENSE) No definition line found',
#   'NODE_4874_length_20116_cov_37.345077_6;[5516 - 6340] No definition line found',
#   'NODE_5339_length_18576_cov_37.831018_13;[15743 - 16597] No definition line found',
#   'NODE_9574_length_9580_cov_44.215616_1;[4376 - 5215] No definition line found',
#   'NODE_61658_length_1040_cov_1143.640706_1;[9 - 737] No definition line found',
#   'NODE_829_length_74096_cov_65.354085_7;[11940 - 13013] No definition line found',
#   'NODE_11665_length_7441_cov_57.376697_2;[4715 - 5425] No definition line found',
#   'NODE_5143_length_19243_cov_42.491339_7;[12583 - 13422] No definition line found',
#   'NODE_10655_length_8337_cov_41.157627_6;[4047 - 3208] (REVERSE SENSE) No definition line found',
#   'NODE_8934_length_10461_cov_43.715716_10;[5195 - 4359] (REVERSE SENSE) No definition line found',
#   'NODE_866_length_72325_cov_37.472691_52;[34607 - 33936] (REVERSE SENSE) No definition line found',
#   'NODE_6781_length_14418_cov_37.653650_17;[1052 - 447] (REVERSE SENSE) No definition line found',
#   'NODE_52373_length_1210_cov_1.902913_1;[498 - 76] (REVERSE SENSE) No definition line found',
#   'NODE_6984_length_13947_cov_38.879380_3;[3876 - 4259] No definition line found',
#   'NODE_17516_length_4364_cov_81.868206_1;[2671 - 4152] No definition line found',
#   'NODE_5215_length_19019_cov_37.828236_20;[15967 - 16524] No definition line found',
#   'NODE_1465_length_50215_cov_45.222007_18;[43690 - 43097] (REVERSE SENSE) No definition line found',
#   'NODE_3667_length_26145_cov_48.502378_19;[9119 - 5118] (REVERSE SENSE) No definition line found',
#   'NODE_8746_length_10716_cov_29.281041_9;[2330 - 1548] (REVERSE SENSE) No definition line found',
#   'NODE_134624_length_517_cov_187.613636_1;[394 - 5] (REVERSE SENSE) No definition line found',
#   'NODE_2774_length_32621_cov_36.854996_23;[28652 - 28206] (REVERSE SENSE) No definition line found',
#   'NODE_46036_length_1373_cov_634.591821_2;[584 - 3] (REVERSE SENSE) No definition line found',
#   'NODE_6872_length_14173_cov_71.224177_3;[7341 - 7718] No definition line found',
#   'NODE_11077_length_7924_cov_13.114948_4;[2350 - 1562] (REVERSE SENSE) No definition line found',
#   'NODE_6502_length_15105_cov_32.811019_6;[10573 - 9734] (REVERSE SENSE) No definition line found',
#   'NODE_8508_length_11095_cov_11.485025_4;[5969 - 6760] No definition line found',
#   'NODE_70317_length_926_cov_1.542992_1;[179 - 811] No definition line found',
#   'NODE_4742_length_20636_cov_41.178511_13;[16576 - 17028] No definition line found',
#   'NODE_12796_length_6585_cov_96.566994_4;[5411 - 6070] No definition line found',
#   'NODE_145468_length_482_cov_1.654321_1;[465 - 1] (REVERSE SENSE) No definition line found',
#   'NODE_187922_length_374_cov_50.824916_1;[368 - 3] (REVERSE SENSE) No definition line found',
#   'NODE_6984_length_13947_cov_38.879380_2;[3461 - 3895] No definition line found',
#   'NODE_163194_length_431_cov_109.146893_1;[40 - 429] No definition line found',
#   'NODE_3601_length_26483_cov_35.616072_22;[24215 - 23841] (REVERSE SENSE) No definition line found',
#   'NODE_19693_length_3759_cov_2.326453_4;[3150 - 3536] No definition line found',
#   'NODE_8_length_920040_cov_17.887887_833;[694754 - 686502] (REVERSE SENSE) No definition line found',
#   'NODE_160797_length_438_cov_1.152355_1;[426 - 1] (REVERSE SENSE) No definition line found',
#   'NODE_171_length_238445_cov_572.810663_248;[204023 - 198330] (REVERSE SENSE) No definition line found',
#   'NODE_311_length_156469_cov_32.611502_212;[109351 - 103493] (REVERSE SENSE) No definition line found',
#   'NODE_25832_length_2666_cov_10.276555_3;[2582 - 3] (REVERSE SENSE) No definition line found',
#   'NODE_15_length_759953_cov_292.559295_262;[262786 - 265116] No definition line found',
#   'NODE_197_length_219627_cov_52.866117_27;[36342 - 38183] No definition line found',
#   'NODE_152_length_259012_cov_32.238044_218;[213792 - 216185] No definition line found',
#   'NODE_9657_length_9486_cov_41.815390_5;[5475 - 5990] No definition line found',
#   'NODE_38_length_520036_cov_47.857456_203;[291333 - 293378] No definition line found',
#   'NODE_27_length_600914_cov_14.349319_580;[124145 - 122577] (REVERSE SENSE) No definition line found',
#   'NODE_179_length_230196_cov_11.871036_47;[72084 - 73925] No definition line found',
#   'NODE_132_length_285120_cov_137.485885_215;[209327 - 214951] No definition line found',
#   'NODE_2364_length_36824_cov_1984.494571_9;[32770 - 30290] (REVERSE SENSE) No definition line found',
#   'NODE_254_length_184797_cov_7.251294_105;[101709 - 104363] No definition line found',
#   'NODE_377_length_136897_cov_6.550351_176;[122647 - 113297] (REVERSE SENSE) No definition line found',
#   'NODE_1634_length_47073_cov_31.715572_51;[45640 - 37724] (REVERSE SENSE) No definition line found',
#   'NODE_3763_length_25504_cov_3.576867_6;[3254 - 5728] No definition line found',
#   'NODE_113_length_322384_cov_46.569383_318;[69075 - 66415] (REVERSE SENSE) No definition line found',
#   'NODE_4384_length_22242_cov_940.677600_3;[1650 - 2402] No definition line found',
#   'NODE_398_length_128959_cov_17.006463_86;[95877 - 98300] No definition line found',
#   'NODE_619_length_90376_cov_5.509109_46;[41368 - 43188] No definition line found',
#   'NODE_330_length_150702_cov_302.813457_253;[57831 - 52093] (REVERSE SENSE) No definition line found',
#   'NODE_14578_length_5562_cov_2.695716_2;[140 - 2185] No definition line found',
#   'NODE_155_length_252422_cov_128.823373_158;[151593 - 153968] No definition line found',
#   'NODE_395_length_129935_cov_617.085062_224;[40243 - 37604] (REVERSE SENSE) No definition line found',
#   'NODE_153_length_255781_cov_13.970744_62;[126207 - 128102] No definition line found',
#   'NODE_182_length_228583_cov_79.382664_47;[39084 - 40595] No definition line found',
#   'NODE_48_length_497299_cov_6.449061_169;[141115 - 143460] No definition line found',
#   'NODE_6496_length_15111_cov_1016.212452_3;[7843 - 9474] No definition line found',
#   'NODE_6701_length_14585_cov_3.780604_1;[244 - 2841] No definition line found',
#   'NODE_117_length_315731_cov_6.054322_363;[290010 - 287830] (REVERSE SENSE) No definition line found',
#   'NODE_53743_length_1180_cov_2.126020_1;[28 - 966] No definition line found',
#   'NODE_8688_length_10798_cov_2.900009_6;[7831 - 10629] No definition line found',
#   'NODE_15287_length_5216_cov_4.023545_6;[4461 - 2026] (REVERSE SENSE) No definition line found',
#   'NODE_4297_length_22640_cov_6.481496_2;[905 - 15658] No definition line found',
#   'NODE_4572_length_21411_cov_2.919518_3;[2649 - 4451] No definition line found',
#   'NODE_24607_length_2830_cov_2.762078_2;[616 - 2829] No definition line found',
#   'NODE_9289_length_9944_cov_2.221851_18;[5057 - 2613] (REVERSE SENSE) No definition line found',
#   'NODE_965_length_66675_cov_6.078110_86;[31973 - 30357] (REVERSE SENSE) No definition line found',
#   'NODE_20805_length_3501_cov_2.607477_2;[2285 - 3499] No definition line found',
#   'NODE_115_length_316723_cov_17.494170_17;[24651 - 28568] No definition line found',
#   'NODE_1_length_1214521_cov_6.930895_1878;[423901 - 422735] (REVERSE SENSE) No definition line found',
#   'NODE_65_length_422212_cov_6.412126_503;[390883 - 388169] (REVERSE SENSE) No definition line found',
#   'NODE_531_length_103019_cov_5.844194_147;[81829 - 79943] (REVERSE SENSE) No definition line found',
#   'NODE_13626_length_6093_cov_7.413564_4;[2378 - 4231] No definition line found',
#   'NODE_19755_length_3746_cov_3.259471_4;[2434 - 2] (REVERSE SENSE) No definition line found',
#   'NODE_5023_length_19616_cov_937.917959_5;[7529 - 9577] No definition line found',
#   'NODE_8232_length_11555_cov_2.784893_21;[4593 - 3097] (REVERSE SENSE) No definition line found',
#   'NODE_173_length_232916_cov_265.596429_426;[45182 - 42522] (REVERSE SENSE) No definition line found',
#   'NODE_38137_length_1675_cov_2.742178_1;[1623 - 73] (REVERSE SENSE) No definition line found',
#   'NODE_3018_length_30458_cov_4.146045_60;[6868 - 4469] (REVERSE SENSE) No definition line found',
#   'NODE_11733_length_7373_cov_2.742462_15;[1531 - 2] (REVERSE SENSE) No definition line found',
#   'NODE_50189_length_1261_cov_1.277872_2;[778 - 2] (REVERSE SENSE) No definition line found',
#   'NODE_35_length_543908_cov_16.984931_392;[525381 - 526898] No definition line found',
#   'NODE_32_length_556671_cov_424.843629_80;[147462 - 148964] No definition line found',
#   'NODE_145_length_273263_cov_31.304994_495;[59696 - 58605] (REVERSE SENSE) No definition line found',
#   'NODE_38562_length_1656_cov_2.459785_1;[1439 - 3] (REVERSE SENSE) No definition line found',
#   'NODE_741_length_79403_cov_185.477208_114;[54775 - 52463] (REVERSE SENSE) No definition line found',
#   'NODE_21626_length_3339_cov_2.077866_2;[1927 - 2673] No definition line found',
#   'NODE_9207_length_10065_cov_2.478274_4;[6587 - 7192] No definition line found',
#   'NODE_217_length_208486_cov_6.840141_154;[119771 - 121276] No definition line found',
#   'NODE_208_length_212550_cov_43.804855_251;[16263 - 14707] (REVERSE SENSE) No definition line found',
#   'NODE_15194_length_5265_cov_2.682151_1;[483 - 2510] No definition line found',
#   'NODE_34_length_549459_cov_93.351604_851;[322400 - 320046] (REVERSE SENSE) No definition line found',
#   'NODE_9_length_911479_cov_90.897796_472;[453340 - 454851] No definition line found',
#   'NODE_12484_length_6796_cov_1290.573002_1;[19 - 2499] No definition line found',
#   'NODE_6433_length_15242_cov_3.264820_13;[14901 - 12997] (REVERSE SENSE) No definition line found',
#   'NODE_10_length_908469_cov_12.406104_30;[51694 - 53403] No definition line found',
#   'NODE_39_length_517803_cov_7.286389_789;[253042 - 251264] (REVERSE SENSE) No definition line found',
#   'NODE_53948_length_1176_cov_1.693358_1;[216 - 1175] No definition line found',
#   'NODE_2119_length_39630_cov_2.885243_25;[33761 - 35431] No definition line found',
#   'NODE_1064_length_63035_cov_6.873725_79;[36545 - 33525] (REVERSE SENSE) No definition line found',
#   'NODE_28709_length_2337_cov_3.107522_2;[67 - 2064] No definition line found',
#   'NODE_62_length_444389_cov_18.131093_102;[149210 - 152152] No definition line found',
#   'NODE_80950_length_820_cov_1.360700_2;[708 - 1] (REVERSE SENSE) No definition line found',
#   'NODE_135_length_281329_cov_13.280030_127;[232303 - 233835] No definition line found',
#   'NODE_176_length_232184_cov_8.619279_91;[69255 - 71813] No definition line found',
#   'NODE_23925_length_2930_cov_2.353663_3;[1486 - 2] (REVERSE SENSE) No definition line found',
#   'NODE_1_length_1214521_cov_6.930895_63;[65903 - 67675] No definition line found',
#   'NODE_20309_length_3613_cov_2.466629_6;[1486 - 2] (REVERSE SENSE) No definition line found',
#   'NODE_2425_length_36271_cov_3.294192_30;[26880 - 29057] No definition line found',
#   'NODE_157_length_250643_cov_11.185995_221;[208428 - 210728] No definition line found']}

# %%
total_ids = sum(len(id) for id in genome_scaffold_orfs_descr.values())
total_ids
# Out:
# 280

# %% [markdown]
# ### Extracting scaffolds (30000nt downstream and upstream of the viral genes) containing viral genes detected by HMMER.
# ### Scaffolds shorter than 20000 nts are discarded.

# %%
scaffolds_of_interest = []

def run_blastdbcmd(id, genome_db, outscaffold, range):
    command = ["blastdbcmd", "-entry", str(id), "-db", genome_db, "-out", outscaffold, "-range", range]
    print(f"Running command: {' '.join(command)}")  

    result = subprocess.run(command, text=True, capture_output=True)

    if result.returncode != 0:
        print(f"Warning: blastdbcmd failed for ID {id} in database {genome_db}. Error: {result.stderr}")
        if os.path.exists(outscaffold):
            os.remove(outscaffold)
        return False, None

    if os.path.exists(outscaffold) and os.path.getsize(outscaffold) > 0:
        record = SeqIO.read(outscaffold, "fasta")
        if len(record.seq) < 20000:
            print(f"Notice: Scaffold {id} is shorter than 20000 nucleotides, removing file.")
            os.remove(outscaffold)
            return False, None
        else:
            scaffolds_of_interest.append(id)
            return True, len(record.seq)
    else:
        print(f"Notice: No scaffold file created for ID {id}.")
        return False, None

scaffolds_dir = "/home/majnusova/all/projects/plv/data/eve_outscaffolds/"
blastables_outdir = "/home/majnusova/all/projects/plv/data/blastables/"
prot_database = "_orfs."

for genome, ids in genome_scaffold_orfs_descr.items(): #ids = NODE_15445_length_2031_cov_23.9084_2;[1007 - 1726] No definition line found
    print(f"Processing genome: {genome}")  
    genome_dir = os.path.join(scaffolds_dir, genome)
    os.makedirs(genome_dir, exist_ok=True)
    for i in ids:
        res_scaf_orf = i.split(";")[0]
        id_full, descr = i.split(';')
        id = id_full.rsplit('_', 1)[0]  
        print(f"Processing ID: {id}")  

        if "REVERSE" in descr:
            start_orf_part = descr.split(" - ")[1]
            start_orf = start_orf_part.split("]")[0]
            end_orf_part = descr.split(" - ")[0]
            end_orf = end_orf_part.split("[")[1]
        else:
            start_orf_part = descr.split(" - ")[0]
            start_orf = start_orf_part.split("[")[1]
            end_orf_part = descr.split(" - ")[1]
            end_orf = end_orf_part.split("]")[0]

        end_extended_orf = int(end_orf) + 30000 # when a range passed to blastdbcmd exceeds the length of the scaffold, blastdbcmd will by default extract the whole scaffold! :-)
        if int(start_orf) <= 30000:
            start_extended_orf = 1
        else:
            start_extended_orf = int(start_orf) - 30000

        for filename in os.listdir(blastables_outdir):
            if prot_database not in filename:
                base_name = filename.split('.')[0]
                genome_db = os.path.join(blastables_outdir, base_name)
                outscaffold = f"{genome_dir}/{res_scaf_orf}.fasta"

                success, scaffold_length = run_blastdbcmd(id, genome_db, outscaffold, f"{start_extended_orf}-{end_extended_orf}")
                if success:
                    break

print('Scaffolds of interest:', scaffolds_of_interest)
# Out:
# Processing genome: Chic10_scaffolds
# Processing ID: NODE_5080_length_5696_cov_26.6876
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Notice: Scaffold NODE_5080_length_5696_cov_26.6876 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Notice: Scaffold NODE_5080_length_5696_cov_26.6876 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Notice: Scaffold NODE_5080_length_5696_cov_26.6876 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Notice: Scaffold NODE_5080_length_5696_cov_26.6876 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Notice: Scaffold NODE_5080_length_5696_cov_26.6876 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/in -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/in. Error: BLAST Database error: No alias or index file found for nucleotide database [/home/majnusova/all/projects/plv/data/blastables/in] in search path [/home/majnusova/all/ngs_scripts::]
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Notice: Scaffold NODE_5080_length_5696_cov_26.6876 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Notice: Scaffold NODE_5080_length_5696_cov_26.6876 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/blastn -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/blastn. Error: BLAST Database error: No alias or index file found for nucleotide database [/home/majnusova/all/projects/plv/data/blastables/blastn] in search path [/home/majnusova/all/ngs_scripts::]
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Notice: Scaffold NODE_5080_length_5696_cov_26.6876 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Notice: Scaffold NODE_5080_length_5696_cov_26.6876 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Notice: Scaffold NODE_5080_length_5696_cov_26.6876 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5080_length_5696_cov_26.6876 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5080_length_5696_cov_26.6876_1.fasta -range 1-31389
# Warning: blastdbcmd failed for ID NODE_5080_length_5696_cov_26.6876 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5080_length_5696_cov_26.6876
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Processing ID: NODE_381_length_27838_cov_14.2215
# Running command: blastdbcmd -entry NODE_381_length_27838_cov_14.2215 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_381_length_27838_cov_14.2215_25.fasta -range 1-37239
# Processing ID: NODE_7293_length_4272_cov_22.9291
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Notice: Scaffold NODE_7293_length_4272_cov_22.9291 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Notice: Scaffold NODE_7293_length_4272_cov_22.9291 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Notice: Scaffold NODE_7293_length_4272_cov_22.9291 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Notice: Scaffold NODE_7293_length_4272_cov_22.9291 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Notice: Scaffold NODE_7293_length_4272_cov_22.9291 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/in -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/in. Error: BLAST Database error: No alias or index file found for nucleotide database [/home/majnusova/all/projects/plv/data/blastables/in] in search path [/home/majnusova/all/ngs_scripts::]
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Notice: Scaffold NODE_7293_length_4272_cov_22.9291 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Notice: Scaffold NODE_7293_length_4272_cov_22.9291 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/blastn -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/blastn. Error: BLAST Database error: No alias or index file found for nucleotide database [/home/majnusova/all/projects/plv/data/blastables/blastn] in search path [/home/majnusova/all/ngs_scripts::]
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Notice: Scaffold NODE_7293_length_4272_cov_22.9291 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Notice: Scaffold NODE_7293_length_4272_cov_22.9291 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Notice: Scaffold NODE_7293_length_4272_cov_22.9291 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_7293_length_4272_cov_22.9291 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_7293_length_4272_cov_22.9291_3.fasta -range 1-31285
# Warning: blastdbcmd failed for ID NODE_7293_length_4272_cov_22.9291 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_7293_length_4272_cov_22.9291
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Processing ID: NODE_5397_length_5445_cov_37.4879
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Notice: Scaffold NODE_5397_length_5445_cov_37.4879 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Notice: Scaffold NODE_5397_length_5445_cov_37.4879 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Notice: Scaffold NODE_5397_length_5445_cov_37.4879 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Notice: Scaffold NODE_5397_length_5445_cov_37.4879 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Notice: Scaffold NODE_5397_length_5445_cov_37.4879 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/in -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/in. Error: BLAST Database error: No alias or index file found for nucleotide database [/home/majnusova/all/projects/plv/data/blastables/in] in search path [/home/majnusova/all/ngs_scripts::]
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Notice: Scaffold NODE_5397_length_5445_cov_37.4879 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Notice: Scaffold NODE_5397_length_5445_cov_37.4879 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/blastn -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/blastn. Error: BLAST Database error: No alias or index file found for nucleotide database [/home/majnusova/all/projects/plv/data/blastables/blastn] in search path [/home/majnusova/all/ngs_scripts::]
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Notice: Scaffold NODE_5397_length_5445_cov_37.4879 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Notice: Scaffold NODE_5397_length_5445_cov_37.4879 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5397_length_5445_cov_37.4879 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Chic10_scaffolds/NODE_5397_length_5445_cov_37.4879_2.fasta -range 1-31711
# Warning: blastdbcmd failed for ID NODE_5397_length_5445_cov_37.4879 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5397_length_5445_cov_37.4879
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# ...
#
# Running command: blastdbcmd -entry NODE_8905_length_10501_cov_38.608020 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_8905_length_10501_cov_38.608020_2.fasta -range 1-31775
# Notice: Scaffold NODE_8905_length_10501_cov_38.608020 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_8905_length_10501_cov_38.608020 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_8905_length_10501_cov_38.608020_2.fasta -range 1-31775
# Notice: Scaffold NODE_8905_length_10501_cov_38.608020 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_8905_length_10501_cov_38.608020 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_8905_length_10501_cov_38.608020_2.fasta -range 1-31775
# Warning: blastdbcmd failed for ID NODE_8905_length_10501_cov_38.608020 in database /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_8905_length_10501_cov_38.608020
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_8905_length_10501_cov_38.608020 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_8905_length_10501_cov_38.608020_2.fasta -range 1-31775
# Notice: Scaffold NODE_8905_length_10501_cov_38.608020 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_8905_length_10501_cov_38.608020 -db /home/majnusova/all/projects/plv/data/blastables/blastn -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_8905_length_10501_cov_38.608020_2.fasta -range 1-31775
# Warning: blastdbcmd failed for ID NODE_8905_length_10501_cov_38.608020 in database /home/majnusova/all/projects/plv/data/blastables/blastn. Error: BLAST Database error: No alias or index file found for nucleotide database [/home/majnusova/all/projects/plv/data/blastables/blastn] in search path [/home/majnusova/all/ngs_scripts::]
#
# Running command: blastdbcmd -entry NODE_8905_length_10501_cov_38.608020 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_8905_length_10501_cov_38.608020_2.fasta -range 1-31775
# Warning: blastdbcmd failed for ID NODE_8905_length_10501_cov_38.608020 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_8905_length_10501_cov_38.608020
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_8905_length_10501_cov_38.608020 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_8905_length_10501_cov_38.608020_2.fasta -range 1-31775
# Warning: blastdbcmd failed for ID NODE_8905_length_10501_cov_38.608020 in database /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_8905_length_10501_cov_38.608020
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_8905_length_10501_cov_38.608020 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_8905_length_10501_cov_38.608020_2.fasta -range 1-31775
# Notice: Scaffold NODE_8905_length_10501_cov_38.608020 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_8905_length_10501_cov_38.608020 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_8905_length_10501_cov_38.608020_2.fasta -range 1-31775
# Warning: blastdbcmd failed for ID NODE_8905_length_10501_cov_38.608020 in database /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_8905_length_10501_cov_38.608020
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_8905_length_10501_cov_38.608020 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_8905_length_10501_cov_38.608020_2.fasta -range 1-31775
# Warning: blastdbcmd failed for ID NODE_8905_length_10501_cov_38.608020 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_8905_length_10501_cov_38.608020
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_8905_length_10501_cov_38.608020 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_8905_length_10501_cov_38.608020_2.fasta -range 1-31775
# Warning: blastdbcmd failed for ID NODE_8905_length_10501_cov_38.608020 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_8905_length_10501_cov_38.608020
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_8905_length_10501_cov_38.608020 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_8905_length_10501_cov_38.608020_2.fasta -range 1-31775
# Warning: blastdbcmd failed for ID NODE_8905_length_10501_cov_38.608020 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_8905_length_10501_cov_38.608020
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_8905_length_10501_cov_38.608020 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_8905_length_10501_cov_38.608020_2.fasta -range 1-31775
# Warning: blastdbcmd failed for ID NODE_8905_length_10501_cov_38.608020 in database /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_8905_length_10501_cov_38.608020
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_8905_length_10501_cov_38.608020 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_8905_length_10501_cov_38.608020_2.fasta -range 1-31775
# Notice: Scaffold NODE_8905_length_10501_cov_38.608020 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_8905_length_10501_cov_38.608020 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_8905_length_10501_cov_38.608020_2.fasta -range 1-31775
# Warning: blastdbcmd failed for ID NODE_8905_length_10501_cov_38.608020 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_8905_length_10501_cov_38.608020
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Processing ID: NODE_1923_length_42336_cov_37.970586
# Running command: blastdbcmd -entry NODE_1923_length_42336_cov_37.970586 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_1923_length_42336_cov_37.970586_26.fasta -range 6535-67209
# Warning: blastdbcmd failed for ID NODE_1923_length_42336_cov_37.970586 in database /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_1923_length_42336_cov_37.970586
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_1923_length_42336_cov_37.970586 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_1923_length_42336_cov_37.970586_26.fasta -range 6535-67209
# Processing ID: NODE_5165_length_19175_cov_36.990494
# Running command: blastdbcmd -entry NODE_5165_length_19175_cov_36.990494 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_5165_length_19175_cov_36.990494_16.fasta -range 1-45536
# Warning: blastdbcmd failed for ID NODE_5165_length_19175_cov_36.990494 in database /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5165_length_19175_cov_36.990494
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5165_length_19175_cov_36.990494 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_5165_length_19175_cov_36.990494_16.fasta -range 1-45536
# Notice: Scaffold NODE_5165_length_19175_cov_36.990494 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5165_length_19175_cov_36.990494 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_5165_length_19175_cov_36.990494_16.fasta -range 1-45536
# Warning: blastdbcmd failed for ID NODE_5165_length_19175_cov_36.990494 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5165_length_19175_cov_36.990494
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5165_length_19175_cov_36.990494 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_5165_length_19175_cov_36.990494_16.fasta -range 1-45536
# Warning: blastdbcmd failed for ID NODE_5165_length_19175_cov_36.990494 in database /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1. Error: Error: [blastdbcmd] Entry not found: NODE_5165_length_19175_cov_36.990494
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5165_length_19175_cov_36.990494 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_5165_length_19175_cov_36.990494_16.fasta -range 1-45536
# Notice: Scaffold NODE_5165_length_19175_cov_36.990494 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5165_length_19175_cov_36.990494 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_5165_length_19175_cov_36.990494_16.fasta -range 1-45536
# Warning: blastdbcmd failed for ID NODE_5165_length_19175_cov_36.990494 in database /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5165_length_19175_cov_36.990494
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5165_length_19175_cov_36.990494 -db /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_5165_length_19175_cov_36.990494_16.fasta -range 1-45536
# Warning: blastdbcmd failed for ID NODE_5165_length_19175_cov_36.990494 in database /home/majnusova/all/projects/plv/data/blastables/Chic10_scaffolds. Error: Error: [blastdbcmd] Entry not found: NODE_5165_length_19175_cov_36.990494
# Error: [blastdbcmd] Entry or entries not found in BLAST database
#
# Running command: blastdbcmd -entry NODE_5165_length_19175_cov_36.990494 -db /home/majnusova/all/projects/plv/data/blastables/Characiopsis_New_scaffolds -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_5165_length_19175_cov_36.990494_16.fasta -range 1-45536
# Notice: Scaffold NODE_5165_length_19175_cov_36.990494 is shorter than 20000 nucleotides, removing file.
# Running command: blastdbcmd -entry NODE_5165_length_19175_cov_36.990494 -db /home/majnusova/all/projects/plv/data/blastables/Vischeria_C74_genome_v1 -out /home/majnusova/all/projects/plv/data/eve_outscaffolds/Characiopsis_New_scaffolds/NODE_5165_length_19175_cov_36.990494_16.fasta -range 1-45536
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 65
#      62 genome_db = os.path.join(blastables_outdir, base_name)
#      63 outscaffold = f"{genome_dir}/{res_scaf_orf}.fasta"
# ---> 65 success, scaffold_length = run_blastdbcmd(id, genome_db, outscaffold, f"{start_extended_orf}-{end_extended_orf}")
#      66 if success:
#      67     break
#
# Cell In[10], line 7, in run_blastdbcmd(id, genome_db, outscaffold, range)
#       4 command = ["blastdbcmd", "-entry", str(id), "-db", genome_db, "-out", outscaffold, "-range", range]
#       5 print(f"Running command: {' '.join(command)}")
# ----> 7 result = subprocess.run(command, text=True, capture_output=True)
#       9 if result.returncode != 0:
#      10     print(f"Warning: blastdbcmd failed for ID {id} in database {genome_db}. Error: {result.stderr}")
#
# File ~/miniconda3/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File ~/miniconda3/lib/python3.10/subprocess.py:1154, in Popen.communicate(self, input, timeout)
#    1151     endtime = None
#    1153 try:
# -> 1154     stdout, stderr = self._communicate(input, endtime, timeout)
#    1155 except KeyboardInterrupt:
#    1156     # https://bugs.python.org/issue25942
#    1157     # See the detailed comment in .wait().
#    1158     if timeout is not None:
#
# File ~/miniconda3/lib/python3.10/subprocess.py:2021, in Popen._communicate(self, input, endtime, orig_timeout)
#    2014     self._check_timeout(endtime, orig_timeout,
#    2015                         stdout, stderr,
#    2016                         skip_check_and_raise=True)
#    2017     raise RuntimeError(  # Impossible :)
#    2018         '_check_timeout(..., skip_check_and_raise=True) '
#    2019         'failed to raise TimeoutExpired.')
# -> 2021 ready = selector.select(timeout)
#    2022 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2024 # XXX Rewrite these to use non-blocking I/O on the file
#    2025 # objects; they are no longer using C stdio!
#
# File ~/miniconda3/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# ### list containing IDs of scaffolds (not orfs) - input for blastn

# %%
#sedi, v poradku; jen ids skafoldu nad inclusion treshold a 20000+
len(scaffolds_of_interest)
# Out:
# 137

# %%
#len(scaffolds_of_interest)
scaffolds_of_interest
# Out:
# ['NODE_381_length_27838_cov_14.2215',
#  'NODE_352_length_29307_cov_12.7034',
#  'NODE_45_length_194274_cov_4.45832',
#  'NODE_16_length_371769_cov_13.539',
#  'NODE_1_length_1589435_cov_13.0886',
#  'NODE_10_length_626405_cov_4.34645',
#  'NODE_70_length_144148_cov_190.155',
#  'NODE_498_length_23434_cov_17.1238',
#  'NODE_33_length_241831_cov_197.129',
#  'NODE_89_length_113149_cov_3.22244',
#  'NODE_33_length_241831_cov_197.129',
#  'NODE_146_length_60639_cov_3.37158',
#  'NODE_95_length_100189_cov_309.803',
#  'NODE_122_length_74444_cov_387.187',
#  'NODE_381_length_27838_cov_14.2215',
#  'NODE_55_length_165510_cov_190.906',
#  'NODE_58_length_162532_cov_4.15186',
#  'NODE_98_length_98422_cov_62.5464',
#  'NODE_43_length_199121_cov_7.50572',
#  'NODE_2_length_969053_cov_7.62238',
#  'NODE_37_length_230641_cov_4.40646',
#  'NODE_11_length_515168_cov_3.2278',
#  'NODE_63_length_153037_cov_4.46219',
#  'NODE_244_length_37664_cov_11.8205',
#  'NODE_104_length_85964_cov_12.9853',
#  'NODE_66_length_150458_cov_3.12336',
#  'NODE_3_length_955702_cov_6.81221',
#  'NODE_28_length_282822_cov_9.9159',
#  'NODE_13_length_427009_cov_190.15',
#  'NODE_94_length_101213_cov_13.992',
#  'NODE_2_length_969053_cov_7.62238',
#  'NODE_95_length_100189_cov_309.803',
#  'NODE_3_length_955702_cov_6.81221',
#  'NODE_312_length_31651_cov_4.15834',
#  'NODE_2_length_969053_cov_7.62238',
#  'NODE_34_length_241557_cov_7.5501',
#  'NODE_9_length_666414_cov_4.15495',
#  'NODE_26_length_312622_cov_7.43917',
#  'NODE_1_length_1589435_cov_13.0886',
#  'Vischeria_C74_contig_15',
#  'Vischeria_C74_contig_12',
#  'Vischeria_C74_contig_9',
#  'Vischeria_C74_contig_46',
#  'Vischeria_C74_contig_4',
#  'Vischeria_C74_contig_13',
#  'Vischeria_C74_contig_27',
#  'Vischeria_C74_contig_13',
#  'Vischeria_C74_contig_33',
#  'Vischeria_C74_contig_10',
#  'Vischeria_C74_contig_10',
#  'Vischeria_C74_contig_19',
#  'Vischeria_C74_contig_2',
#  'Vischeria_C74_contig_4',
#  'Vischeria_C74_contig_33',
#  'Vischeria_C74_contig_16',
#  'Vischeria_C74_contig_25',
#  'Vischeria_C74_contig_9',
#  'Vischeria_C74_contig_13',
#  'Vischeria_C74_contig_9',
#  'Vischeria_C74_contig_8',
#  'Vischeria_C74_contig_3',
#  'Vischeria_C74_contig_18',
#  'Vischeria_C74_contig_9',
#  'Vischeria_C74_contig_16',
#  'Vischeria_C74_contig_12',
#  'Vischeria_C74_contig_16',
#  'NODE_541_length_101851_cov_46.471309',
#  'NODE_55_length_463973_cov_37.984469',
#  'NODE_1103_length_61346_cov_37.814180',
#  'NODE_320_length_153881_cov_39.008816',
#  'NODE_3853_length_25035_cov_37.882483',
#  'NODE_4047_length_24047_cov_37.496871',
#  'NODE_1923_length_42336_cov_37.970586',
#  'NODE_520_length_104572_cov_40.248251',
#  'NODE_867_length_72283_cov_40.422873',
#  'NODE_4244_length_22945_cov_43.032228',
#  'NODE_4874_length_20116_cov_37.345077',
#  'NODE_829_length_74096_cov_65.354085',
#  'NODE_866_length_72325_cov_37.472691',
#  'NODE_1465_length_50215_cov_45.222007',
#  'NODE_3667_length_26145_cov_48.502378',
#  'NODE_2774_length_32621_cov_36.854996',
#  'NODE_4742_length_20636_cov_41.178511',
#  'NODE_3601_length_26483_cov_35.616072',
#  'NODE_8_length_920040_cov_17.887887',
#  'NODE_171_length_238445_cov_572.810663',
#  'NODE_311_length_156469_cov_32.611502',
#  'NODE_15_length_759953_cov_292.559295',
#  'NODE_197_length_219627_cov_52.866117',
#  'NODE_152_length_259012_cov_32.238044',
#  'NODE_38_length_520036_cov_47.857456',
#  'NODE_27_length_600914_cov_14.349319',
#  'NODE_179_length_230196_cov_11.871036',
#  'NODE_132_length_285120_cov_137.485885',
#  'NODE_2364_length_36824_cov_1984.494571',
#  'NODE_254_length_184797_cov_7.251294',
#  'NODE_377_length_136897_cov_6.550351',
#  'NODE_1634_length_47073_cov_31.715572',
#  'NODE_3763_length_25504_cov_3.576867',
#  'NODE_113_length_322384_cov_46.569383',
#  'NODE_4384_length_22242_cov_940.677600',
#  'NODE_398_length_128959_cov_17.006463',
#  'NODE_619_length_90376_cov_5.509109',
#  'NODE_330_length_150702_cov_302.813457',
#  'NODE_155_length_252422_cov_128.823373',
#  'NODE_395_length_129935_cov_617.085062',
#  'NODE_153_length_255781_cov_13.970744',
#  'NODE_182_length_228583_cov_79.382664',
#  'NODE_48_length_497299_cov_6.449061',
#  'NODE_117_length_315731_cov_6.054322',
#  'NODE_4297_length_22640_cov_6.481496',
#  'NODE_4572_length_21411_cov_2.919518',
#  'NODE_965_length_66675_cov_6.078110',
#  'NODE_115_length_316723_cov_17.494170',
#  'NODE_1_length_1214521_cov_6.930895',
#  'NODE_65_length_422212_cov_6.412126',
#  'NODE_531_length_103019_cov_5.844194',
#  'NODE_173_length_232916_cov_265.596429',
#  'NODE_3018_length_30458_cov_4.146045',
#  'NODE_35_length_543908_cov_16.984931',
#  'NODE_32_length_556671_cov_424.843629',
#  'NODE_145_length_273263_cov_31.304994',
#  'NODE_741_length_79403_cov_185.477208',
#  'NODE_217_length_208486_cov_6.840141',
#  'NODE_208_length_212550_cov_43.804855',
#  'NODE_34_length_549459_cov_93.351604',
#  'NODE_9_length_911479_cov_90.897796',
#  'NODE_10_length_908469_cov_12.406104',
#  'NODE_39_length_517803_cov_7.286389',
#  'NODE_2119_length_39630_cov_2.885243',
#  'NODE_1064_length_63035_cov_6.873725',
#  'NODE_62_length_444389_cov_18.131093',
#  'NODE_135_length_281329_cov_13.280030',
#  'NODE_176_length_232184_cov_8.619279',
#  'NODE_1_length_1214521_cov_6.930895',
#  'NODE_2425_length_36271_cov_3.294192',
#  'NODE_157_length_250643_cov_11.185995']

# %%
scaffolds_of_interest= ['NODE_381_length_27838_cov_14.2215',
 'NODE_352_length_29307_cov_12.7034',
 'NODE_45_length_194274_cov_4.45832',
 'NODE_16_length_371769_cov_13.539',
 'NODE_1_length_1589435_cov_13.0886',
 'NODE_10_length_626405_cov_4.34645',
 'NODE_70_length_144148_cov_190.155',
 'NODE_498_length_23434_cov_17.1238',
 'NODE_33_length_241831_cov_197.129',
 'NODE_89_length_113149_cov_3.22244',
 'NODE_33_length_241831_cov_197.129',
 'NODE_146_length_60639_cov_3.37158',
 'NODE_95_length_100189_cov_309.803',
 'NODE_122_length_74444_cov_387.187',
 'NODE_381_length_27838_cov_14.2215',
 'NODE_55_length_165510_cov_190.906',
 'NODE_27_length_600914_cov_14.349319',
 'NODE_179_length_230196_cov_11.871036',
 'NODE_132_length_285120_cov_137.485885',
 'NODE_2364_length_36824_cov_1984.494571',
 'NODE_254_length_184797_cov_7.251294',
 'NODE_377_length_136897_cov_6.550351',
 'NODE_1634_length_47073_cov_31.715572',
 'NODE_3763_length_25504_cov_3.576867',
 'NODE_113_length_322384_cov_46.569383',
 'NODE_4384_length_22242_cov_940.677600',
 'NODE_398_length_128959_cov_17.006463',
 'NODE_619_length_90376_cov_5.509109',
 'NODE_330_length_150702_cov_302.813457',
 'NODE_155_length_252422_cov_128.823373',
 'NODE_395_length_129935_cov_617.085062',
 'NODE_153_length_255781_cov_13.970744',
 'NODE_182_length_228583_cov_79.382664',
 'NODE_48_length_497299_cov_6.449061',
 'NODE_117_length_315731_cov_6.054322',
 'NODE_4297_length_22640_cov_6.481496',
 'NODE_4572_length_21411_cov_2.919518',
 'NODE_965_length_66675_cov_6.078110',
 'NODE_115_length_316723_cov_17.494170',
 'NODE_1_length_1214521_cov_6.930895',
 'NODE_65_length_422212_cov_6.412126',
 'NODE_531_length_103019_cov_5.844194',
 'NODE_173_length_232916_cov_265.596429',
 'NODE_3018_length_30458_cov_4.146045',
 'NODE_35_length_543908_cov_16.984931',
 'NODE_32_length_556671_cov_424.843629',
 'NODE_145_length_273263_cov_31.304994',
 'NODE_741_length_79403_cov_185.477208',
 'NODE_217_length_208486_cov_6.840141',
 'NODE_208_length_212550_cov_43.804855',
 'NODE_34_length_549459_cov_93.351604',
 'NODE_9_length_911479_cov_90.897796',
 'NODE_10_length_908469_cov_12.406104',
 'NODE_39_length_517803_cov_7.286389',
 'NODE_2119_length_39630_cov_2.885243',
 'NODE_1064_length_63035_cov_6.873725',
 'NODE_62_length_444389_cov_18.131093',
 'NODE_135_length_281329_cov_13.280030',
 'NODE_176_length_232184_cov_8.619279',
 'NODE_1_length_1214521_cov_6.930895',
 'NODE_2425_length_36271_cov_3.294192',
 'NODE_157_length_250643_cov_11.185995']

# %%
#set protoze potrebujeme scaffold pouzit jako seqidlist v ramci blastn jen jednou
set_scaffolds_of_interest = set(scaffolds_of_interest)
len(set_scaffolds_of_interest)
# Out:
# 118

# %%
# ted potrebujeme srovnat scaffolds_of_interest s genome_scaffold_ids a pak to pouzijeme pro seqidlist
# ziskame dict: genomes a jejich filtered scaffolds (vice virovych orfu na jednom skafoldu -> redundance)
real_genome_scaffold_ids = {}

for genome, ids in genome_scaffold_orfs_descr.items():
    truncated_ids = [id.split(';')[0] for id in ids] 
    real_genome_scaffold_ids[genome] = truncated_ids

filtered_genome_scaffold_ids = {}

for genome, ids in real_genome_scaffold_ids.items():
    for scaffold_id in ids:
        truncated_id = scaffold_id.split('_')[:-1] 
        truncated_id = '_'.join(truncated_id)
        if truncated_id in set_scaffolds_of_interest:
            if genome not in filtered_genome_scaffold_ids:
                filtered_genome_scaffold_ids[genome] = []  # initialize the list if it doesn't exist
            filtered_genome_scaffold_ids[genome].append(scaffold_id)  

', 'NODE_320_length_153881_cov_39.008816_191', 'NODE_3853_length_25035_cov_37.882483_16', 'NODE_4047_length_24047_cov_37.496871_5', 'NODE_1923_length_42336_cov_37.970586_26', 'NODE_520_length_104572_cov_40.248251_16', 'NODE_867_length_72283_cov_40.422873_20', 'NODE_4244_length_22945_cov_43.032228_19', 'NODE_4874_length_20116_cov_37.345077_6', 'NODE_829_length_74096_cov_65.354085_7', 'NODE_866_length_72325_cov_37.472691_52', 'NODE_1465_length_50215_cov_45.222007_18', 'NODE_3667_length_26145_cov_48.502378_19', 'NODE_2774_length_32621_cov_36.854996_23', 'NODE_4742_length_20636_cov_41.178511_13', 'NODE_3601_length_26483_cov_35.616072_22', 'NODE_8_length_920040_cov_17.887887_833', 'NODE_171_length_238445_cov_572.810663_248', 'NODE_311_length_156469_cov_32.611502_212', 'NODE_15_length_759953_cov_292.559295_262', 'NODE_197_length_219627_cov_52.866117_27', 'NODE_152_length_259012_cov_32.238044_218', 'NODE_38_length_520036_cov_47.857456_203', 'NODE_27_length_600914_cov_14.349319_580', 'NODE_179_length_230196_cov_11.871036_47', 'NODE_132_length_285120_cov_137.485885_215', 'NODE_2364_length_36824_cov_1984.494571_9', 'NODE_254_length_184797_cov_7.251294_105', 'NODE_377_length_136897_cov_6.550351_176', 'NODE_1634_length_47073_cov_31.715572_51', 'NODE_3763_length_25504_cov_3.576867_6', 'NODE_113_length_322384_cov_46.569383_318', 'NODE_4384_length_22242_cov_940.677600_3', 'NODE_ ...

# %%
sum(len(id) for id in filtered_genome_scaffold_ids.values())
# Out:
# 137

# %% [markdown]
# ## BLASTn to identify viral repeats - otestovat, jak to bude hledat repetice kdyz se bude blastovat ne proti celemu skafoldu ale proti tem frakcim /home/majnusova/all/projects/plv/data/eve_outscaffolds/

# %%
def blastn_repeats(query, output, database, seqid, outfmt):
    command = ["blastn",
               "-query", str(query), 
               "-out", str(output),
               "-db", str(database), 
               "-strand", "minus",
              # "-dust", "no",
            #   "-word_size", "9",
               "-seqidlist", str(seqid), 
               "-num_threads", "5", # zmenit na clusteru
               "-outfmt", str(outfmt)]
    subprocess.run(command, check=True) 


output_dir = "/home/majnusova/all/projects/plv/data/blastn_tirs/"
blastables_outdir = "/home/majnusova/all/projects/plv/data/blastables/"
path_to_input = "/home/majnusova/all/projects/plv/data/eve_outscaffolds/"

for genome, scaffold_ids in filtered_genome_scaffold_ids.items():
    database = f"{blastables_outdir}/{genome}" 
    outdir = os.path.join(output_dir, genome)
    os.makedirs(outdir, exist_ok=True)
    
    for scaffold_id in scaffold_ids:  
        query_file = f"{scaffold_id}.fasta" # scaffold_id = NODE_135_length_281329_cov_13.280030_127 -> NODE_135_length_281329_cov_13.280030_127.fasta
        query = os.path.join(path_to_input, genome, query_file) #/home/majnusova/all/projects/plv/data/eve_outscaffolds/NODE_135_length_281329_cov_13.280030_127.fasta
        seqidlist_file = '_'.join(scaffold_id.split('_')[:-1]) #NODE_135_length_281329_cov_13.280030
        seqidlist_path = os.path.join(outdir, f"{seqidlist_file}_seqid.txt") #/home/majnusova/all/projects/plv/data/alias_test/NODE_135_length_281329_cov_13.280030
        
        with open(seqidlist_path, 'w') as file:
            file.write(seqidlist_file + '\n')  

        output_file = f"{scaffold_id}_repeats.txt"
        output = os.path.join(outdir, output_file)
        output_file2 = f"{scaffold_id}_repeats_human.txt"
        output2 = os.path.join(outdir, output_file2)

    # Checking if the query file exists to avoid the error!
        if os.path.exists(query):
            # outfmt 6 output
            blastn_repeats(query, output, database, seqidlist_path, 5) # should be 5
            # human-readable output
            blastn_repeats(query, output2, database, seqidlist_path, 0)
        else:
            print(f"Query file {query} does not exist, skipping this scaffold ID.")
# Out:
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist
# Warning: [blastn] To obtain better run time performance, please run blastdb_aliastool -seqid_file_in <INPUT_FILE_NAME> -seqid_file_out <OUT_FILE_NAME> and use <OUT_FILE_NAME> as the argument to -seqidlist

# %% [markdown]
# ## Searching for suitable repeats in the blast outputs

# %%
TIRs: 200-1200 nt long; musi byt od sebe vzdalene 15 000-35 000
len(hsp.match)) = delka zalignovaneho useku vcetne gapu a mismatchu (Identities = 338/403 (84%)) -> len(hsp.match)) = 403

# %%
from Bio.Blast import NCBIXML

blastout_dir = "/home/majnusova/all/projects/plv/data/blastn_tirs/Vischeria_C74_genome_v1/Vischeria_C74_contig_16_620_repeats.txt"

hsp_info = {}

with open(blastout_dir) as blast_handle:
    blast_records = NCBIXML.parse(blast_handle)
    for blast_record in blast_records:
        for hsp_num, hsp in enumerate(alignment.hsps, start=1): # enumerating each HSP - the number will be used as a key to store additional values 
            hsp_info[hsp_num] = {            
            'bit_score': hsp.bits,
            'score': hsp.score,
            'evalue': hsp.expect,
            'gaps': hsp.gaps,
            'identities': hsp.identities,
            'aln_len' : len(hsp.match)
            }
hsp_info
# Out:
# {1: {'bit_score': 974.305,
#   'score': 527.0,
#   'evalue': 0.0,
#   'gaps': 0,
#   'identities': 527,
#   'aln_len': 527},
#  2: {'bit_score': 974.305,
#   'score': 527.0,
#   'evalue': 0.0,
#   'gaps': 0,
#   'identities': 527,
#   'aln_len': 527},
#  3: {'bit_score': 366.757,
#   'score': 198.0,
#   'evalue': 6.93911e-100,
#   'gaps': 19,
#   'identities': 338,
#   'aln_len': 403},
#  4: {'bit_score': 344.597,
#   'score': 186.0,
#   'evalue': 3.25137e-93,
#   'gaps': 4,
#   'identities': 208,
#   'aln_len': 218},
#  5: {'bit_score': 331.671,
#   'score': 179.0,
#   'evalue': 2.53131e-89,
#   'gaps': 5,
#   'identities': 274,
#   'aln_len': 320},
#  6: {'bit_score': 327.977,
#   'score': 177.0,
#   'evalue': 3.27446e-88,
#   'gaps': 2,
#   'identities': 200,
#   'aln_len': 211},
#  7: {'bit_score': 313.204,
#   'score': 169.0,
#   'evalue': 9.16885e-84,
#   'gaps': 1,
#   'identities': 216,
#   'aln_len': 239},
#  8: {'bit_score': 302.124,
#   'score': 163.0,
#   'evalue': 1.98471e-80,
#   'gaps': 6,
#   'identities': 206,
#   'aln_len': 226},
#  9: {'bit_score': 296.584,
#   'score': 160.0,
#   'evalue': 9.23395e-79,
#   'gaps': 1,
#   'identities': 213,
#   'aln_len': 239},
#  10: {'bit_score': 294.738,
#   'score': 159.0,
#   'evalue': 3.32112e-78,
#   'gaps': 17,
#   'identities': 266,
#   'aln_len': 315},
#  11: {'bit_score': 287.351,
#   'score': 155.0,
#   'evalue': 5.5574e-76,
#   'gaps': 52,
#   'identities': 445,
#   'aln_len': 577},
#  12: {'bit_score': 281.811,
#   'score': 152.0,
#   'evalue': 2.58561e-74,
#   'gaps': 10,
#   'identities': 217,
#   'aln_len': 247},
#  13: {'bit_score': 279.964,
#   'score': 151.0,
#   'evalue': 9.2995e-74,
#   'gaps': 0,
#   'identities': 169,
#   'aln_len': 178},
#  14: {'bit_score': 279.964,
#   'score': 151.0,
#   'evalue': 9.2995e-74,
#   'gaps': 0,
#   'identities': 169,
#   'aln_len': 178},
#  15: {'bit_score': 263.345,
#   'score': 142.0,
#   'evalue': 9.36553e-69,
#   'gaps': 1,
#   'identities': 167,
#   'aln_len': 179},
#  16: {'bit_score': 259.651,
#   'score': 140.0,
#   'evalue': 1.21151e-67,
#   'gaps': 14,
#   'identities': 209,
#   'aln_len': 240},
#  17: {'bit_score': 257.805,
#   'score': 139.0,
#   'evalue': 4.35736e-67,
#   'gaps': 2,
#   'identities': 166,
#   'aln_len': 179},
#  18: {'bit_score': 255.958,
#   'score': 138.0,
#   'evalue': 1.56718e-66,
#   'gaps': 4,
#   'identities': 164,
#   'aln_len': 176},
#  19: {'bit_score': 254.111,
#   'score': 137.0,
#   'evalue': 5.6366e-66,
#   'gaps': 8,
#   'identities': 171,
#   'aln_len': 186},
#  20: {'bit_score': 248.571,
#   'score': 134.0,
#   'evalue': 2.62245e-64,
#   'gaps': 1,
#   'identities': 147,
#   'aln_len': 153},
#  21: {'bit_score': 244.878,
#   'score': 132.0,
#   'evalue': 3.39236e-63,
#   'gaps': 11,
#   'identities': 272,
#   'aln_len': 339},
#  22: {'bit_score': 244.878,
#   'score': 132.0,
#   'evalue': 3.39236e-63,
#   'gaps': 1,
#   'identities': 157,
#   'aln_len': 169},
#  23: {'bit_score': 244.878,
#   'score': 132.0,
#   'evalue': 3.39236e-63,
#   'gaps': 13,
#   'identities': 201,
#   'aln_len': 232},
#  24: {'bit_score': 244.878,
#   'score': 132.0,
#   'evalue': 3.39236e-63,
#   'gaps': 4,
#   'identities': 166,
#   'aln_len': 182},
#  25: {'bit_score': 237.491,
#   'score': 128.0,
#   'evalue': 5.67661e-61,
#   'gaps': 1,
#   'identities': 203,
#   'aln_len': 240},
#  26: {'bit_score': 235.645,
#   'score': 127.0,
#   'evalue': 2.04167e-60,
#   'gaps': 1,
#   'identities': 162,
#   'aln_len': 179},
#  27: {'bit_score': 226.412,
#   'score': 122.0,
#   'evalue': 1.22877e-57,
#   'gaps': 8,
#   'identities': 180,
#   'aln_len': 207},
#  28: {'bit_score': 226.412,
#   'score': 122.0,
#   'evalue': 1.22877e-57,
#   'gaps': 0,
#   'identities': 134,
#   'aln_len': 140},
#  29: {'bit_score': 224.565,
#   'score': 121.0,
#   'evalue': 4.41945e-57,
#   'gaps': 1,
#   'identities': 170,
#   'aln_len': 194},
#  30: {'bit_score': 224.565,
#   'score': 121.0,
#   'evalue': 4.41945e-57,
#   'gaps': 0,
#   'identities': 137,
#   'aln_len': 145},
#  31: {'bit_score': 222.718,
#   'score': 120.0,
#   'evalue': 1.58952e-56,
#   'gaps': 1,
#   'identities': 157,
#   'aln_len': 175},
#  32: {'bit_score': 219.025,
#   'score': 118.0,
#   'evalue': 2.05617e-55,
#   'gaps': 3,
#   'identities': 140,
#   'aln_len': 150},
#  33: {'bit_score': 215.332,
#   'score': 116.0,
#   'evalue': 2.65982e-54,
#   'gaps': 0,
#   'identities': 132,
#   'aln_len': 140},
#  34: {'bit_score': 215.332,
#   'score': 116.0,
#   'evalue': 2.65982e-54,
#   'gaps': 20,
#   'identities': 260,
#   'aln_len': 327},
#  35: {'bit_score': 213.485,
#   'score': 115.0,
#   'evalue': 9.56642e-54,
#   'gaps': 1,
#   'identities': 130,
#   'aln_len': 137},
#  36: {'bit_score': 213.485,
#   'score': 115.0,
#   'evalue': 9.56642e-54,
#   'gaps': 1,
#   'identities': 130,
#   'aln_len': 137},
#  37: {'bit_score': 207.945,
#   'score': 112.0,
#   'evalue': 4.45082e-52,
#   'gaps': 0,
#   'identities': 122,
#   'aln_len': 127},
#  38: {'bit_score': 206.098,
#   'score': 111.0,
#   'evalue': 1.6008e-51,
#   'gaps': 2,
#   'identities': 144,
#   'aln_len': 160},
#  39: {'bit_score': 202.405,
#   'score': 109.0,
#   'evalue': 2.07077e-50,
#   'gaps': 1,
#   'identities': 126,
#   'aln_len': 134},
#  40: {'bit_score': 198.712,
#   'score': 107.0,
#   'evalue': 2.67871e-49,
#   'gaps': 3,
#   'identities': 173,
#   'aln_len': 205},
#  41: {'bit_score': 198.712,
#   'score': 107.0,
#   'evalue': 2.67871e-49,
#   'gaps': 7,
#   'identities': 147,
#   'aln_len': 165},
#  42: {'bit_score': 193.172,
#   'score': 104.0,
#   'evalue': 1.24628e-47,
#   'gaps': 6,
#   'identities': 167,
#   'aln_len': 197},
#  43: {'bit_score': 191.325,
#   'score': 103.0,
#   'evalue': 4.48242e-47,
#   'gaps': 2,
#   'identities': 128,
#   'aln_len': 140},
#  44: {'bit_score': 191.325,
#   'score': 103.0,
#   'evalue': 4.48242e-47,
#   'gaps': 5,
#   'identities': 154,
#   'aln_len': 178},
#  45: {'bit_score': 187.632,
#   'score': 101.0,
#   'evalue': 5.79838e-46,
#   'gaps': 21,
#   'identities': 240,
#   'aln_len': 304},
#  46: {'bit_score': 187.632,
#   'score': 101.0,
#   'evalue': 5.79838e-46,
#   'gaps': 2,
#   'identities': 128,
#   'aln_len': 141},
#  47: {'bit_score': 187.632,
#   'score': 101.0,
#   'evalue': 5.79838e-46,
#   'gaps': 5,
#   'identities': 178,
#   'aln_len': 215},
#  48: {'bit_score': 185.785,
#   'score': 100.0,
#   'evalue': 2.08547e-45,
#   'gaps': 8,
#   'identities': 190,
#   'aln_len': 233},
#  49: {'bit_score': 183.939,
#   'score': 99.0,
#   'evalue': 7.50068e-45,
#   'gaps': 1,
#   'identities': 134,
#   'aln_len': 151},
#  50: {'bit_score': 183.939,
#   'score': 99.0,
#   'evalue': 7.50068e-45,
#   'gaps': 9,
#   'identities': 158,
#   'aln_len': 185},
#  51: {'bit_score': 183.939,
#   'score': 99.0,
#   'evalue': 7.50068e-45,
#   'gaps': 2,
#   'identities': 178,
#   'aln_len': 217},
#  52: {'bit_score': 182.092,
#   'score': 98.0,
#   'evalue': 2.69772e-44,
#   'gaps': 13,
#   'identities': 147,
#   'aln_len': 168},
#  53: {'bit_score': 178.399,
#   'score': 96.0,
#   'evalue': 3.48973e-43,
#   'gaps': 8,
#   'identities': 156,
#   'aln_len': 184},
#  54: {'bit_score': 174.705,
#   'score': 94.0,
#   'evalue': 4.51425e-42,
#   'gaps': 1,
#   'identities': 139,
#   'aln_len': 161},
#  55: {'bit_score': 172.859,
#   'score': 93.0,
#   'evalue': 1.62361e-41,
#   'gaps': 3,
#   'identities': 131,
#   'aln_len': 149},
#  56: {'bit_score': 172.859,
#   'score': 93.0,
#   'evalue': 1.62361e-41,
#   'gaps': 0,
#   'identities': 119,
#   'aln_len': 132},
#  57: {'bit_score': 172.859,
#   'score': 93.0,
#   'evalue': 1.62361e-41,
#   'gaps': 3,
#   'identities': 147,
#   'aln_len': 173},
#  58: {'bit_score': 171.012,
#   'score': 92.0,
#   'evalue': 5.83955e-41,
#   'gaps': 0,
#   'identities': 104,
#   'aln_len': 110},
#  59: {'bit_score': 169.165,
#   'score': 91.0,
#   'evalue': 2.10027e-40,
#   'gaps': 3,
#   'identities': 125,
#   'aln_len': 141},
#  60: {'bit_score': 165.472,
#   'score': 89.0,
#   'evalue': 2.71688e-39,
#   'gaps': 0,
#   'identities': 121,
#   'aln_len': 137},
#  61: {'bit_score': 163.625,
#   'score': 88.0,
#   'evalue': 9.77162e-39,
#   'gaps': 5,
#   'identities': 115,
#   'aln_len': 127},
#  62: {'bit_score': 163.625,
#   'score': 88.0,
#   'evalue': 9.77162e-39,
#   'gaps': 27,
#   'identities': 278,
#   'aln_len': 366},
#  63: {'bit_score': 159.932,
#   'score': 86.0,
#   'evalue': 1.26404e-37,
#   'gaps': 1,
#   'identities': 115,
#   'aln_len': 129},
#  64: {'bit_score': 158.086,
#   'score': 85.0,
#   'evalue': 4.54629e-37,
#   'gaps': 0,
#   'identities': 109,
#   'aln_len': 121},
#  65: {'bit_score': 150.699,
#   'score': 81.0,
#   'evalue': 7.60756e-35,
#   'gaps': 25,
#   'identities': 212,
#   'aln_len': 271},
#  66: {'bit_score': 150.699,
#   'score': 81.0,
#   'evalue': 7.60756e-35,
#   'gaps': 1,
#   'identities': 106,
#   'aln_len': 118},
#  67: {'bit_score': 147.006,
#   'score': 79.0,
#   'evalue': 9.841e-34,
#   'gaps': 0,
#   'identities': 99,
#   'aln_len': 109},
#  68: {'bit_score': 147.006,
#   'score': 79.0,
#   'evalue': 9.841e-34,
#   'gaps': 0,
#   'identities': 89,
#   'aln_len': 94},
#  69: {'bit_score': 145.159,
#   'score': 78.0,
#   'evalue': 3.53945e-33,
#   'gaps': 1,
#   'identities': 97,
#   'aln_len': 106},
#  70: {'bit_score': 139.619,
#   'score': 75.0,
#   'evalue': 1.64675e-31,
#   'gaps': 20,
#   'identities': 219,
#   'aln_len': 286},
#  71: {'bit_score': 139.619,
#   'score': 75.0,
#   'evalue': 1.64675e-31,
#   'gaps': 1,
#   'identities': 98,
#   'aln_len': 109},
#  72: {'bit_score': 135.926,
#   'score': 73.0,
#   'evalue': 2.1302e-30,
#   'gaps': 6,
#   'identities': 114,
#   'aln_len': 133},
#  73: {'bit_score': 134.079,
#   'score': 72.0,
#   'evalue': 7.66157e-30,
#   'gaps': 0,
#   'identities': 88,
#   'aln_len': 96},
#  74: {'bit_score': 134.079,
#   'score': 72.0,
#   'evalue': 7.66157e-30,
#   'gaps': 0,
#   'identities': 142,
#   'aln_len': 177},
#  75: {'bit_score': 132.232,
#   'score': 71.0,
#   'evalue': 2.75559e-29,
#   'gaps': 8,
#   'identities': 135,
#   'aln_len': 165},
#  76: {'bit_score': 128.539,
#   'score': 69.0,
#   'evalue': 3.56458e-28,
#   'gaps': 2,
#   'identities': 90,
#   'aln_len': 100},
#  77: {'bit_score': 128.539,
#   'score': 69.0,
#   'evalue': 3.56458e-28,
#   'gaps': 13,
#   'identities': 164,
#   'aln_len': 208},
#  78: {'bit_score': 126.692,
#   'score': 68.0,
#   'evalue': 1.28205e-27,
#   'gaps': 3,
#   'identities': 86,
#   'aln_len': 94},
#  79: {'bit_score': 124.846,
#   'score': 67.0,
#   'evalue': 4.61108e-27,
#   'gaps': 4,
#   'identities': 107,
#   'aln_len': 126},
#  80: {'bit_score': 121.153,
#   'score': 65.0,
#   'evalue': 5.96481e-26,
#   'gaps': 9,
#   'identities': 122,
#   'aln_len': 148},
#  81: {'bit_score': 119.306,
#   'score': 64.0,
#   'evalue': 2.14533e-25,
#   'gaps': 0,
#   'identities': 90,
#   'aln_len': 103},
#  82: {'bit_score': 115.613,
#   'score': 62.0,
#   'evalue': 2.77515e-24,
#   'gaps': 2,
#   'identities': 97,
#   'aln_len': 114},
#  83: {'bit_score': 115.613,
#   'score': 62.0,
#   'evalue': 2.77515e-24,
#   'gaps': 1,
#   'identities': 93,
#   'aln_len': 108},
#  84: {'bit_score': 113.766,
#   'score': 61.0,
#   'evalue': 9.98123e-24,
#   'gaps': 23,
#   'identities': 171,
#   'aln_len': 220},
#  85: {'bit_score': 113.766,
#   'score': 61.0,
#   'evalue': 9.98123e-24,
#   'gaps': 1,
#   'identities': 96,
#   'aln_len': 113},
#  86: {'bit_score': 113.766,
#   'score': 61.0,
#   'evalue': 9.98123e-24,
#   'gaps': 9,
#   'identities': 118,
#   'aln_len': 144},
#  87: {'bit_score': 111.919,
#   'score': 60.0,
#   'evalue': 3.58989e-23,
#   'gaps': 7,
#   'identities': 116,
#   'aln_len': 142},
#  88: {'bit_score': 110.073,
#   'score': 59.0,
#   'evalue': 1.29115e-22,
#   'gaps': 0,
#   'identities': 79,
#   'aln_len': 89},
#  89: {'bit_score': 108.226,
#   'score': 58.0,
#   'evalue': 4.64381e-22,
#   'gaps': 0,
#   'identities': 94,
#   'aln_len': 112},
#  90: {'bit_score': 106.379,
#   'score': 57.0,
#   'evalue': 1.67021e-21,
#   'gaps': 0,
#   'identities': 83,
#   'aln_len': 96},
#  91: {'bit_score': 106.379,
#   'score': 57.0,
#   'evalue': 1.67021e-21,
#   'gaps': 3,
#   'identities': 81,
#   'aln_len': 92},
#  92: {'bit_score': 106.379,
#   'score': 57.0,
#   'evalue': 1.67021e-21,
#   'gaps': 2,
#   'identities': 80,
#   'aln_len': 91},
#  93: {'bit_score': 106.379,
#   'score': 57.0,
#   'evalue': 1.67021e-21,
#   'gaps': 4,
#   'identities': 81,
#   'aln_len': 92},
#  94: {'bit_score': 106.379,
#   'score': 57.0,
#   'evalue': 1.67021e-21,
#   'gaps': 1,
#   'identities': 80,
#   'aln_len': 91},
#  95: {'bit_score': 104.533,
#   'score': 56.0,
#   'evalue': 6.00715e-21,
#   'gaps': 0,
#   'identities': 70,
#   'aln_len': 77},
#  96: {'bit_score': 104.533,
#   'score': 56.0,
#   'evalue': 6.00715e-21,
#   'gaps': 1,
#   'identities': 83,
#   'aln_len': 96},
#  97: {'bit_score': 102.686,
#   'score': 55.0,
#   'evalue': 2.16056e-20,
#   'gaps': 3,
#   'identities': 79,
#   'aln_len': 90},
#  98: {'bit_score': 102.686,
#   'score': 55.0,
#   'evalue': 2.16056e-20,
#   'gaps': 3,
#   'identities': 79,
#   'aln_len': 90},
#  99: {'bit_score': 102.686,
#   'score': 55.0,
#   'evalue': 2.16056e-20,
#   'gaps': 3,
#   'identities': 79,
#   'aln_len': 90},
#  100: {'bit_score': 95.2994,
#   'score': 51.0,
#   'evalue': 3.61538e-18,
#   'gaps': 13,
#   'identities': 106,
#   'aln_len': 130},
#  101: {'bit_score': 93.4528,
#   'score': 50.0,
#   'evalue': 1.30032e-17,
#   'gaps': 2,
#   'identities': 69,
#   'aln_len': 78},
#  102: {'bit_score': 93.4528,
#   'score': 50.0,
#   'evalue': 1.30032e-17,
#   'gaps': 18,
#   'identities': 131,
#   'aln_len': 167},
#  103: {'bit_score': 93.4528,
#   'score': 50.0,
#   'evalue': 1.30032e-17,
#   'gaps': 9,
#   'identities': 105,
#   'aln_len': 130},
#  104: {'bit_score': 89.7595,
#   'score': 48.0,
#   'evalue': 1.68207e-16,
#   'gaps': 2,
#   'identities': 67,
#   'aln_len': 76},
#  105: {'bit_score': 89.7595,
#   'score': 48.0,
#   'evalue': 1.68207e-16,
#   'gaps': 5,
#   'identities': 77,
#   'aln_len': 90},
#  106: {'bit_score': 89.7595,
#   'score': 48.0,
#   'evalue': 1.68207e-16,
#   'gaps': 3,
#   'identities': 70,
#   'aln_len': 80},
#  107: {'bit_score': 87.9128,
#   'score': 47.0,
#   'evalue': 6.0498e-16,
#   'gaps': 3,
#   'identities': 83,
#   'aln_len': 100},
#  108: {'bit_score': 84.2195,
#   'score': 45.0,
#   'evalue': 7.82591e-15,
#   'gaps': 6,
#   'identities': 76,
#   'aln_len': 90},
#  109: {'bit_score': 82.3729,
#   'score': 44.0,
#   'evalue': 2.8147e-14,
#   'gaps': 7,
#   'identities': 112,
#   'aln_len': 144},
#  110: {'bit_score': 78.6796,
#   'score': 42.0,
#   'evalue': 3.64104e-13,
#   'gaps': 4,
#   'identities': 70,
#   'aln_len': 83},
#  111: {'bit_score': 71.293,
#   'score': 38.0,
#   'evalue': 6.09275e-11,
#   'gaps': 1,
#   'identities': 61,
#   'aln_len': 72},
#  112: {'bit_score': 67.5997,
#   'score': 36.0,
#   'evalue': 7.88147e-10,
#   'gaps': 2,
#   'identities': 47,
#   'aln_len': 52},
#  113: {'bit_score': 62.0597,
#   'score': 33.0,
#   'evalue': 3.66689e-08,
#   'gaps': 0,
#   'identities': 35,
#   'aln_len': 36},
#  114: {'bit_score': 58.3664,
#   'score': 31.0,
#   'evalue': 4.74343e-07,
#   'gaps': 0,
#   'identities': 33,
#   'aln_len': 34}}

# %%
blastout_dir = "/home/majnusova/all/projects/plv/data/blastn_tirs/"
#def find_tirs(blastout, singleline_scaffold, outf)
hsp_info = {}
for genome in filtered_genome_scaffold_ids.keys(): #dict obsahuje genomy a ids virovych scaffoldu vcetne _orfnumber
    fullpath = os.path.join(blastout_dir, genome)
    for blastout in os.listdir(fullpath):
        blastout_path = os.path.join(fullpath, blastout)
        if blastout.endswith("repeats.txt"):
            with open(blastout_path) as blast_handle:
                blast_records = NCBIXML.parse(blast_handle)
                for blast_record in blast_records:
                    for hsp_num, hsp in enumerate(alignment.hsps, start=1): # enumerating each HSP - the number will be used as a key to store additional values 
                        hsp_info[hsp_num] = {            
                        'bit_score': hsp.bits,
                        'score': hsp.score,
                        'evalue': hsp.expect,
                        'gaps': hsp.gaps,
                        'identities': hsp.identities,
                        'aln_len' : len(hsp.match)
                        }
hsp_info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 12
#      10                 blast_records = NCBIXML.parse(blast_handle)
#      11                 for blast_record in blast_records:
# ---> 12                     for hsp_num, hsp in enumerate(alignment.hsps, start=1): # enumerating each HSP - the number will be used as a key to store additional values
#      13                         hsp_info[hsp_num] = {
#      14                         'bit_score': hsp.bits,
#      15                         'score': hsp.score,
#    (...)
#      19                         'aln_len' : len(hsp.match)
#      20                         }
#      21 hsp_info
#
# NameError: name 'alignment' is not defined

# %%
from collections import defaultdict
import os
from Bio.Blast import NCBIXML

blastout_dir = "/home/majnusova/all/projects/plv/data/blastn_tirs/"

for genome in filtered_genome_scaffold_ids.keys():
    fullpath = os.path.join(blastout_dir, genome)
    for blastout in os.listdir(fullpath):
        blastout_path = os.path.join(fullpath, blastout)
        if blastout.endswith("repeats.txt"):
            hsp_info = defaultdict(list)
            with open(blastout_path) as blast_handle:
                blast_records = NCBIXML.parse(blast_handle)
                for blast_record in blast_records:
                    for alignment in blast_record.alignments:
                        for hsp in alignment.hsps:
                            key = (hsp.bits, hsp.score, hsp.expect, hsp.gaps, hsp.identities, len(hsp.match))
                            hsp_info[key].append(hsp)

            for key, hsps in hsp_info.items():
                if len(hsps) > 1:
                    if len(hsp.match) >= 200 and len(hsp.match) <= 1200:
                        print(f"Soubor: {blastout}, Dvojice HSP s identickými hodnotami (bit_score, evalue, identities): {key}")
                        for hsp in hsps:
                            print(f"HSP: bit_score={hsp.bits}, evalue={hsp.expect}, identities={hsp.identities}")
                        print("-----")
# Out:
# Soubor: NODE_352_length_29307_cov_12.7034_4_repeats.txt, Dvojice HSP s identickými hodnotami (bit_score, evalue, identities): (183.939, 99.0, 3.6499e-47, 37, 216, 265)
# HSP: bit_score=183.939, evalue=3.6499e-47, identities=216
# HSP: bit_score=183.939, evalue=3.6499e-47, identities=216
# -----
# Soubor: Vischeria_C74_contig_33_10_repeats.txt, Dvojice HSP s identickými hodnotami (bit_score, evalue, identities): (1157.12, 626.0, 0.0, 1, 637, 642)
# HSP: bit_score=1157.12, evalue=0.0, identities=637
# HSP: bit_score=1157.12, evalue=0.0, identities=637
# -----
# Soubor: NODE_4244_length_22945_cov_43.032228_19_repeats.txt, Dvojice HSP s identickými hodnotami (bit_score, evalue, identities): (558.808, 302.0, 3.18082e-160, 0, 304, 305)
# HSP: bit_score=558.808, evalue=3.18082e-160, identities=304
# HSP: bit_score=558.808, evalue=3.18082e-160, identities=304
# -----
# Soubor: NODE_3601_length_26483_cov_35.616072_22_repeats.txt, Dvojice HSP s identickými hodnotami (bit_score, evalue, identities): (1411.96, 764.0, 0.0, 25, 945, 1029)
# HSP: bit_score=1411.96, evalue=0.0, identities=945
# HSP: bit_score=1411.96, evalue=0.0, identities=945
# -----
# Soubor: NODE_3601_length_26483_cov_35.616072_22_repeats.txt, Dvojice HSP s identickými hodnotami (bit_score, evalue, identities): (893.052, 483.0, 0.0, 102, 1038, 1290)
# HSP: bit_score=893.052, evalue=0.0, identities=1038
# HSP: bit_score=893.052, evalue=0.0, identities=1038
# -----

# %%
----------------------------------------ok

# %% [markdown]
# ## Turning the extracted scaffolds into single line files to make it possible to search for the repeats flanking the EVEs

# %%
scaffolds_dir = "/home/majnusova/all/projects/plv/data/eve_outscaffolds/"
singleline_dir = "/home/majnusova/all/projects/plv/data/eve_singleline_scaffolds/" 

for outscaffold in os.listdir(scaffolds_dir):  #os.listdir lists all files/directories; not paths
    outscaffold_path = os.path.join(scaffolds_dir, outscaffold) # paths to all the files listed
    with open(outscaffold_path, "r") as infile:
        lines = infile.readlines()
    header = lines[0]  # fasta header
    joined_lines = ''.join(line.strip() for line in lines[1:])  # Join all lines except the first

    output_file_path = os.path.join(singleline_dir, outscaffold)  
    with open(output_file_path, "w") as outfile:
        outfile.write(header) 
        outfile.write(joined_lines)

# %% [markdown]
# ### Find suitable repeats and  separate them from the rest of the genome (2x \n at both 5' and 3' end)

# %% [markdown]
# ## prepare blastn to find DRs (shortest one has 48 nt, longest one 101 nt)

# %% [raw]
#  Score = 115 bits (62),  Expect = 5e-21
#  Identities = 62/62 (100%), Gaps = 0/62 (0%)
#  Strand=Plus/Plus
#
# DRs: prohledat 38-160 DRs, query a sbjct musi byt od sebe vzdalene minimalne: 15 000-35 000
# TIRs: 200-1200 nt long; musi byt od sebe vzdalene 15 000-35 000

# %%
kdyz se na jednom scaffoldu nachazi vice virovych proteinu (v hmmmout contig1_2, contig1_13...), tak dat id contigu do setu pro blastn,
aby se to zblastovalo jen jednou (cely skafold) a pak zkusit odentrovat vsechny vhodne repetice, co to najde a hledat pak jestli v nich je 
protein nalezeny hmmerem - kdyz jo, ulozit pod hmmer orf id jako soubor s EVE

# %%
from Bio import SeqIO
from collections import defaultdict

# Načtení sekvence
record = SeqIO.read("sliding_test.fasta", "fasta")
sequence = str(record.seq).upper()

# Funkce pro hledání přímých opakování
def find_direct_repeats(seq, min_size=3, max_size=8):
    repeats = defaultdict(list)
    length = len(seq)
    
    # Procházení sekvencí posuvným oknem
    for size in range(min_size, max_size + 1):
        for i in range(length - size + 1):
            fragment = seq[i:i+size]
            if seq.count(fragment) > 1:
                repeats[fragment].append(i)
    
    # Filtrace opakování, která se vyskytují více než jednou
    direct_repeats = {k: v for k, v in repeats.items() if len(v) > 1}
    return direct_repeats

# Použití funkce
direct_repeats = find_direct_repeats(sequence)
for repeat, positions in direct_repeats.items():
    print(f"Repeat: {repeat}, Positions: {positions}")
# Out:
# Repeat: TGA, Positions: [0, 454, 477, 539, 662, 869, 872, 881, 891, 998, 1106, 1122, 1178, 1228, 1288, 1300, 1359, 1498, 1530, 1728, 1742, 1807, 1817, 1954, 1966, 1970, 2001, 2006, 2050, 2055, 2078, 2086, 2093, 2137, 2146, 2209, 2237, 2540, 2545, 2555, 2602, 2774, 2895, 2953, 2981, 3118, 3207, 3252, 3270, 3302, 3329, 3381, 3401, 3422, 3511, 3575, 3590, 3673, 3681, 3746, 3772, 3788, 3952, 3998, 4054, 4115, 4201, 4204, 4247, 4276, 4283, 4295, 4298, 4322, 4328, 4345, 4376, 4408, 4412, 4503, 4861, 4874, 4886, 4913, 4919, 4987, 4995, 5002, 5007, 5058, 5064, 5172, 5196, 5284, 5299, 5304, 5370, 5409, 5430, 5464, 5479, 5499, 5527, 5634, 5714, 5809, 5866, 5929, 6014, 6210, 6279, 6328, 6385, 6396, 6472, 6493, 6522, 6532, 6564, 6594, 6616, 6625, 6631, 6634, 6684, 6691, 6718, 6730, 6790, 6798, 7003, 7012, 7039, 7153, 7188, 7275, 7330, 7365, 7414, 7462, 7534, 7557, 7581, 7596, 7608, 7627, 7698, 7765, 7768, 7797, 7870, 7873, 7954, 8005, 8008, 8062, 8071, 8076, 8145, 8176, 8179, 8212, 8299, 8370, 8376, 8472, 8485, 8488, 8525, 8571, 8657, 8661, 8727, 8741, 8829, 8843, 8853, 8874, 8908, 8924, 8959, 8963, 9017, 9053, 9065, 9071, 9092, 9104, 9121, 9140, 9143, 9227, 9257, 9281, 9400, 9442, 9457, 9500, 9578, 9608, 9613, 9664, 9727, 9810, 9911, 10031, 10208, 10
# Repeat: ATGCTCCC, Positions: [19597, 20200]
# Repeat: TGCTCCCG, Positions: [19598, 20649]
# Repeat: CCGCTGGA, Positions: [19603, 25289, 25787]
# Repeat: CGCTGGAG, Positions: [19604, 25788]
# Repeat: GCTGGAGG, Positions: [19605, 25789]
# Repeat: CTGGAGGT, Positions: [19606, 20170, 25790]
# Repeat: TGGAGGTC, Positions: [19607, 20171, 24129]
# Repeat: GGAGGTCA, Positions: [19608, 20172, 24130]
# Repeat: AGGTCAAA, Positions: [19610, 20213]
# Repeat: TCAAAGAC, Positions: [19613, 23971]
# Repeat: GGCTGCTC, Positions: [19629, 24400]
# Repeat: CTGCTCCC, Positions: [19631, 20648]
# Repeat: CCTCAATC, Positions: [19658, 22140]
# Repeat: CCGGATGA, Positions: [19669, 24706]
# Repeat: GAAGTGAC, Positions: [19675, 24172]
# Repeat: CACAAACC, Positions: [19692, 26489]
# Repeat: CATCTTGG, Positions: [19710, 22824]
# Repeat: CTTGGCGA, Positions: [19713, 25015]
# Repeat: AGCTGTTG, Positions: [19723, 23290]
# Repeat: TAGAGAAC, Positions: [19736, 25875]
# Repeat: GTTGAATT, Positions: [19759, 22714]
# Repeat: TTGAATTA, Positions: [19760, 22715]
# Repeat: TATAAAAA, Positions: [19766, 20994]
# Repeat: TTGTTTAT, Positions: [19804, 24819]
# Repeat: GTGCTGCT, Positions: [19876, 24486]
# Repeat: CGAACACT, Positions: [19944, 21263]
# Repeat: ATTCCTGA, Positions: [19957, 26740]
# Repeat: ATTCCAGA, Positions: [19987, 24335]
# Repeat: AGGTTAAG, Positions: [20000, 25683]
# Repeat: CTTGTTGA, Positions: [20017, 21796]
# Repeat: TTGTTGAT, Positions: [20018, 21797]
# Repeat: AGTGATGT, Positions: [20029, 22914]
# Repeat: GCTTCCAC, Positions: [20037, 23564]
# Repeat: CACGTCAA, Positions: [20047, 20260]
# Repeat: AACGTCCC, Positions: [20062, 20707]
# Repeat: TCCCGAGG, Positions: [20066, 25579]
# Repeat: ATCCCTGT, Positions: [20080, 24752]
# Repeat: TGTCTGAG, Positions: [20085, 20429]
# Repeat: AGGGTCCC, Positions: [20104, 20749]
# Repeat: GGTCCCCG, Positions: [20106, 25042]
# Repeat: TGTGATCG, Positions: [20130, 20661]
# Repeat: GTGATCGA, Positions: [20131, 20662]
# Repeat: TCGAACCC, Positions: [20135, 22689]
# Repeat: CGAACCCG, Positions: [20136, 22690]
# Repeat: CCAAGCCA, Positions: [20162, 26404]
# Repeat: CAAGCCAC, Positions: [20163, 26405]
# Repeat: ATGTTCAG, Positions: [20179, 24645]
# Repeat: GGTATCCT, Positions: [20186, 21664]
# Repeat: GTATCCTC, Positions: [20187, 21665]
# Repeat: TATCCTCC, Positions: [20188, 21666]
# Repeat: CGACGAGG, Positions: [20208, 26412]
# Repeat: TCAACCCA, Positions: [20222, 20264]
# Repeat: GCTTCCAG, Positions: [20235, 21837]
# Repeat: CAGAAGAC, Positions: [20240, 24893]
# Repeat: ACGTCAAC, Positions: [20261, 24899]
# Repeat: CGTCAACC, Positions: [20262, 24900]
# Repeat: AACCCAGA, Positions: [20266, 21461]
# Repeat: CCACATTA, Positions: [20276, 21747]
# Repeat: TTACATGA, Positions: [20281, 21500]
# Repeat: AGCCATTT, Positions: [20288, 21075]
# Repeat: GCCATTTA, Positions: [20289, 20568]
# Repeat: GGCAGACG, Positions: [20307, 23503]
# Repeat: GCAGACGG, Positions: [20308, 21104, 23504, 25092]
# Repeat: CAGACGGT, Positions: [20309, 25093]
# Repeat: GTGATGTC, Positions: [20315, 22637]
# Repeat: ATGTCGTC, Positions: [20318, 21322]
# Repeat: AATACCAA, Positions: [20328, 25569]
# Repeat: ACCAACGG, Positions: [20331, 26172]
# Repeat: GGTACCGC, Positions: [20337, 23666, 25783]
# Repeat: ACCTTGAA, Positions: [20377, 24273]
# Repeat: CTGATTCG, Positions: [20412, 22971]
# Repeat: CGACGTGT, Positions: [20424, 25768, 26002]
# Repeat: ACGTGTCT, Positions: [20426, 25315]
# Repeat: CGTGTCTG, Positions: [20427, 22208]
# Repeat: AAGTTGAT, Positions: [20437, 26551]
# Repeat: AGTTGATA, Positions: [20438, 26552]
# Repeat: GTTGATAG, Positions: [20439, 26553]
# Repeat: TTAGGTAG, Positions: [20456, 24826]
# Repeat: TAGGTAGA, Positions: [20457, 24827]
# Repeat: GTTGGTGT, Positions: [20469, 21928]
# Repeat: AAACAGAG, Positions: [20484, 24733]
# Repeat: AGCGTTGA, Positions: [20494, 22354]
# Repeat: CGTTGATG, Positions: [20496, 20619, 22356]
# Repeat: CTGGACCT, Positions: [20507, 22213]
# Repeat: TGTCTGTT, Positions: [20519, 22709]
# Repeat: GGTCAACA, Positions: [20550, 24133]
# Repeat: TGCCATTT, Positions: [20567, 21354]
# Repeat: ACTTGTGG, Positions: [20589, 23081]
# Repeat: GACGCTTG, Positions: [20631, 21128]
# Repeat: GACCATTG, Positions: [20678, 21147]
# Repeat: ATTTGCGG, Positions: [20725, 22008]
# Repeat: CTGACTCG, Positions: [20733, 26808]
# Repeat: CTGAAGGG, Positions: [20745, 20823, 23497]
# Repeat: TCGACGCC, Positions: [20765, 25443]
# Repeat: CGCCGACA, Positions: [20769, 21114, 25456]
# Repeat: CCGACACA, Positions: [20771, 23657]
# Repeat: CCGAGGAA, Positions: [20780, 24912]
# Repeat: TGAAGGGC, Positions: [20824, 23498]
# Repeat: GAAGGGCA, Positions: [20825, 23499]
# Repeat: ATATCCCG, Positions: [20832, 25576]
# Repeat: TGAACTGG, Positions: [20841, 22645]
# Repeat: GAACTGGT, Positions: [20842, 24341]
# Repeat: TTCGATGC, Positions: [20869, 23553]
# Repeat: TGCATCAA, Positions: [20874, 22072]
# Repeat: CAGTGTGC, Positions: [20886, 24554]
# Repeat: CTGAATTG, Positions: [20894, 23071]
# Repeat: TGAATTGA, Positions: [20895, 23072]
# Repeat: GAGTAGGA, Positions: [20941, 21400, 21406]
# Repeat: GCTGATAG, Positions: [20952, 26914]
# Repeat: TTCGTGTT, Positions: [20960, 22065]
# Repeat: TCGTGTTG, Positions: [20961, 22066]
# Repeat: TGCGTACG, Positions: [20967, 25310]
# Repeat: TACTCATG, Positions: [20984, 25925]
# Repeat: ACCAGCTG, Positions: [21017, 23287]
# Repeat: TGATTAAT, Positions: [21023, 21569]
# Repeat: TTCCGTAT, Positions: [21033, 23061]
# Repeat: TCCGTATA, Positions: [21034, 23362]
# Repeat: CCGTATAG, Positions: [21035, 23363]
# Repeat: CAATCTCC, Positions: [21062, 23470]
# Repeat: AGCAGACG, Positions: [21103, 25091]
# Repeat: CCGCCGAC, Positions: [21113, 25455]
# Repeat: CGACAGCA, Positions: [21117, 25150]
# Repeat: GACAGCAG, Positions: [21118, 25151]
# Repeat: TGGCACGG, Positions: [21134, 24884]
# Repeat: ACGGTAGC, Positions: [21138, 25799]
# Repeat: TTGCACGA, Positions: [21152, 25415]
# Repeat: GGAATACT, Positions: [21178, 23586]
# Repeat: ACTGTATT, Positions: [21183, 26735]
# Repeat: CTGTATTC, Positions: [21184, 26736]
# Repeat: ATTCGAGC, Positions: [21188, 22974]
# Repeat: GACTCAGA, Positions: [21200, 21777]
# Repeat: ACTCAGAT, Positions: [21201, 21778]
# Repeat: ACGAAGTC, Positions: [21241, 23485]
# Repeat: AGTCCTTC, Positions: [21245, 22188]
# Repeat: GTCCTTCT, Positions: [21246, 22189]
# Repeat: GTCGTGTG, Positions: [21287, 21874]
# Repeat: TCGAATGA, Positions: [21298, 23347]
# Repeat: GATTTTTT, Positions: [21347, 21369]
# Repeat: ATTAGGAT, Positions: [21390, 22431]
# Repeat: AGGAGTAG, Positions: [21398, 21404, 21410, 22761]
# Repeat: AGTAGGAG, Positions: [21401, 21407, 23174]
# Repeat: GAGTAGAA, Positions: [21412, 25025]
# Repeat: AGTAGAAG, Positions: [21413, 25026]
# Repeat: ATGAGCCC, Positions: [21422, 22950]
# Repeat: TTAACCCA, Positions: [21459, 24204]
# Repeat: CAGATTTT, Positions: [21465, 24763]
# Repeat: TTTTCCAG, Positions: [21469, 26338]
# Repeat: ATGACTAA, Positions: [21504, 22553]
# Repeat: ACTAATCC, Positions: [21507, 21519]
# Repeat: CTAATCCT, Positions: [21508, 21520]
# Repeat: TAATCCTA, Positions: [21509, 21521]
# Repeat: TGATGGTC, Positions: [21551, 22359]
# Repeat: GATGGTCT, Positions: [21552, 22360]
# Repeat: CCCAGTAG, Positions: [21593, 22802]
# Repeat: GATATTAT, Positions: [21610, 23753]
# Repeat: TTAACAAA, Positions: [21617, 21737]
# Repeat: TAACAAAG, Positions: [21618, 21738]
# Repeat: GTGTAGCT, Positions: [21629, 24567]
# Repeat: CGGTATCC, Positions: [21663, 24748]
# Repeat: CCTCCTTT, Positions: [21669, 26979]
# Repeat: TTGACCTC, Positions: [21675, 26720]
# Repeat: TTTATTTG, Positions: [21770, 26044]
# Repeat: CAGATACT, Positions: [21781, 26343]
# Repeat: GATACTTG, Positions: [21783, 23078]
# Repeat: ATACTTGT, Positions: [21784, 23079, 24384]
# Repeat: TACTTGTG, Positions: [21785, 23080]
# Repeat: GTGCGTCT, Positions: [21790, 26188]
# Repeat: TCCAGTGC, Positions: [21840, 24872, 26515]
# Repeat: GTGTGTCA, Positions: [21877, 26543]
# Repeat: TGTTGGTG, Positions: [21927, 23791]
# Repeat: TGAATAGA, Positions: [21945, 25871]
# Repeat: GAATAGAG, Positions: [21946, 25872]
# Repeat: AAACTTCT, Positions: [21961, 23726]
# Repeat: TTCTCGGG, Positions: [21965, 26506]
# Repeat: GGGAAATC, Positions: [22031, 22475]
# Repeat: CGGATAGA, Positions: [22098, 25702]
# Repeat: CTTCTCAT, Positions: [22126, 25654]
# Repeat: TGTTACAC, Positions: [22161, 24518]
# Repeat: TGTCTGGA, Positions: [22210, 23631]
# Repeat: GTCTGGAC, Positions: [22211, 23632]
# Repeat: TCATACTT, Positions: [22226, 24466]
# Repeat: GTTGTAGT, Positions: [22246, 23820]
# Repeat: AGGCCCTT, Positions: [22271, 22777]
# Repeat: GGCCCTTC, Positions: [22272, 22778]
# Repeat: TGTGTGTT, Positions: [22296, 23386]
# Repeat: TGTTGAGA, Positions: [22300, 26444]
# Repeat: GTTGAGAG, Positions: [22301, 22561]
# Repeat: TTGAGAGG, Positions: [22302, 26923]
# Repeat: GGCAGGTC, Positions: [22344, 23116]
# Repeat: GGTCTTCA, Positions: [22369, 23120]
# Repeat: TACTTGTA, Positions: [22384, 24385]
# Repeat: TGGACGAC, Positions: [22453, 24861]
# Repeat: GAAATAAA, Positions: [22465, 26901]
# Repeat: AAACTGGG, Positions: [22470, 24218]
# Repeat: AACTGGGA, Positions: [22471, 24219]
# Repeat: CTCCACAT, Positions: [22536, 25504]
# Repeat: CATATTTA, Positions: [22594, 26836]
# Repeat: ATATTTAG, Positions: [22595, 26837]
# Repeat: CTATCGCC, Positions: [22615, 26076, 26115, 26154]
# Repeat: GAACTGGC, Positions: [22646, 25879]
# Repeat: ATACTCGA, Positions: [22657, 26346]
# Repeat: TGATCGTG, Positions: [22665, 24442]
# Repeat: GCCTGGTC, Positions: [22697, 25958]
# Repeat: GGTGTGTC, Positions: [22705, 26542]
# Repeat: CTTCAAGG, Positions: [22756, 23123]
# Repeat: TACCCCCA, Positions: [22798, 22987]
# Repeat: ATCTTGGT, Positions: [22825, 25745]
# Repeat: TCTTGGTG, Positions: [22826, 25746]
# Repeat: TAGTGATG, Positions: [22913, 24071]
# Repeat: ATGTTTTT, Positions: [22918, 23677]
# Repeat: CCACGAAG, Positions: [22940, 23483]
# Repeat: GATGAGCC, Positions: [22949, 24075]
# Repeat: TACTTCAT, Positions: [22962, 24949]
# Repeat: ATTGATAC, Positions: [23075, 23258]
# Repeat: TTGATACT, Positions: [23076, 23259, 26774]
# Repeat: TGATACTT, Positions: [23077, 26775]
# Repeat: ATGGTGTA, Positions: [23089, 24564]
# Repeat: GATCCTAT, Positions: [23100, 23397]
# Repeat: TGCCGCCC, Positions: [23147, 25342]
# Repeat: GAAGTAGG, Positions: [23172, 25234]
# Repeat: TGAGACGA, Positions: [23211, 26360]
# Repeat: AAGATATC, Positions: [23272, 26862]
# Repeat: CCTGGTCA, Positions: [23310, 25959]
# Repeat: TCAGGATG, Positions: [23315, 25374]
# Repeat: CGAATGAC, Positions: [23348, 24109]
# Repeat: GACACGGT, Positions: [23353, 25460]
# Repeat: ACACGGTG, Positions: [23354, 25461]
# Repeat: CACGGTGT, Positions: [23355, 25462]
# Repeat: GATTGGTG, Positions: [23380, 24430]
# Repeat: CCGAGAGA, Positions: [23524, 24920]
# Repeat: TTGCCACG, Positions: [23540, 24956]
# Repeat: TCAAGGTT, Positions: [23578, 26640]
# Repeat: TCAAAACC, Positions: [23599, 25988]
# Repeat: TTTCATAT, Positions: [23682, 26833]
# Repeat: CACATAAC, Positions: [23700, 24245]
# Repeat: AATGTCTT, Positions: [23783, 24279]
# Repeat: TTGGTGGA, Positions: [23793, 24432]
# Repeat: GTGGAGAC, Positions: [23796, 26463]
# Repeat: GGGGTCCA, Positions: [23811, 26511]
# Repeat: GGTGTGGC, Positions: [23837, 25609]
# Repeat: TATGCCGT, Positions: [23886, 24971]
# Repeat: GGTTTGTC, Positions: [23932, 26644]
# Repeat: GTTTGTCT, Positions: [23933, 26645]
# Repeat: AACCAGAA, Positions: [24021, 25754]
# Repeat: ACCAGAAG, Positions: [24022, 25755]
# Repeat: ACTCGAAC, Positions: [24099, 26348]
# Repeat: CTCGAACG, Positions: [24100, 26349]
# Repeat: AATGACCA, Positions: [24111, 25732]
# Repeat: ATGACCAC, Positions: [24112, 25733]
# Repeat: GACCACTC, Positions: [24114, 25257]
# Repeat: GGCACCTT, Positions: [24122, 24270]
# Repeat: GTATGCAT, Positions: [24149, 24365]
# Repeat: CCTGTTAC, Positions: [24195, 24516]
# Repeat: CTGTTACA, Positions: [24196, 24517]
# Repeat: GAATGTCT, Positions: [24278, 25303]
# Repeat: AGAACTGG, Positions: [24340, 25878]
# Repeat: CTGCTCGT, Positions: [24402, 24489]
# Repeat: CGTTGTGA, Positions: [24494, 26355]
# Repeat: GTACGTGT, Positions: [24506, 25313]
# Repeat: TTCATTGC, Positions: [24528, 24952]
# Repeat: GGATACGG, Positions: [24581, 25294]
# Repeat: GTGTATGA, Positions: [24594, 26006]
# Repeat: CGACAGCT, Positions: [24605, 24865]
# Repeat: GACAGCTC, Positions: [24606, 24866]
# Repeat: GAGGGTTG, Positions: [24694, 26066]
# Repeat: CTCATGAT, Positions: [24792, 26435]
# Repeat: CATGATAT, Positions: [24794, 26437]
# Repeat: GTAGAAGT, Positions: [24830, 25027]
# Repeat: CAGCTCCA, Positions: [24868, 25501]
# Repeat: GAGACGAG, Positions: [24924, 26361]
# Repeat: AGACGAGC, Positions: [24925, 26362]
# Repeat: GACGAGCC, Positions: [24926, 26363]
# Repeat: ACGAGCCG, Positions: [24927, 26364]
# Repeat: TGAGCTTC, Positions: [24939, 25977]
# Repeat: CGGAACTG, Positions: [24962, 25865]
# Repeat: GGAACTGA, Positions: [24963, 25866]
# Repeat: CGCATCAT, Positions: [25048, 26588]
# Repeat: GCAGCTCC, Positions: [25155, 25500]
# Repeat: TGTGGTGT, Positions: [25168, 25606]
# Repeat: GTGTACTG, Positions: [25187, 25466]
# Repeat: TGACGTGG, Positions: [25210, 25273]
# Repeat: ACGGTGAA, Positions: [25223, 25298]
# Repeat: ACCGCTGG, Positions: [25288, 25786]
# Repeat: CTCAAGGA, Positions: [25321, 25828]
# Repeat: GTGTAGAG, Positions: [25356, 25556]
# Repeat: CTTGGTGA, Positions: [25402, 25747]
# Repeat: GATGCTCG, Positions: [25438, 25810, 26179]
# Repeat: ATGCTCGA, Positions: [25439, 26180]
# Repeat: CTCGACGC, Positions: [25442, 26812]
# Repeat: GGGTTGAA, Positions: [25544, 26068]
# Repeat: TGTTGAAC, Positions: [25638, 25821]
# Repeat: GTTGAACT, Positions: [25822, 26070]
# Repeat: CGCCGAGC, Positions: [26080, 26119, 26158]
# Repeat: GCCGAGCC, Positions: [26081, 26120, 26159]
# Repeat: CCGAGCCG, Positions: [26082, 26121, 26160]
# Repeat: CGAGCCGT, Positions: [26083, 26122, 26161, 26365]
# Repeat: AGCCGTGT, Positions: [26085, 26124, 26367]
# Repeat: TGTGACGC, Positions: [26090, 26129]
# Repeat: GTGACGCA, Positions: [26091, 26105, 26130, 26144]
# Repeat: GACGCAAT, Positions: [26093, 26107, 26132, 26146]
# Repeat: ACGCAATA, Positions: [26094, 26133]
# Repeat: CGCAATAC, Positions: [26095, 26134]
# Repeat: GCAATACC, Positions: [26096, 26135]
# Repeat: CAATACCG, Positions: [26097, 26136]
# Repeat: ATACCGGT, Positions: [26099, 26138]
# Repeat: TACCGGTG, Positions: [26100, 26139]
# Repeat: ACCGGTGA, Positions: [26101, 26140]
# Repeat: CCGGTGAC, Positions: [26102, 26141]
# Repeat: CGGTGACG, Positions: [26103, 26142]
# Repeat: GGTGACGC, Positions: [26104, 26143]
# Repeat: ACGCAATC, Positions: [26108, 26147]
# Repeat: CGCAATCT, Positions: [26109, 26148]
# Repeat: GCAATCTA, Positions: [26110, 26149]
# Repeat: AATCTATC, Positions: [26112, 26151]
# Repeat: ATCTATCG, Positions: [26113, 26152, 26867]
# Repeat: TCTATCGC, Positions: [26114, 26153]
# Repeat: TGCTCGAG, Positions: [26181, 26524]
# Repeat: CAAGGGCG, Positions: [26384, 26943]
# Repeat: GAGACCCG, Positions: [26448, 26466]
# Repeat: AGACCCGG, Positions: [26449, 26467]
# Repeat: GACCCGGC, Positions: [26450, 26468]
# Repeat: CATGAAAG, Positions: [26573, 26593]
# Repeat: TCCTGAAA, Positions: [26613, 26742]
# Repeat: CAGGCTCT, Positions: [26785, 26963]
# Repeat: AGGCTCTC, Positions: [26786, 26964]

# %% [markdown]
# ## extract orfs between tirs - pujde v pohode i bez vymezeneho TSD. kontrola spravnosti elementu - v orfech musi byt protein identifikovany hmmerem hned na zacatku...

# %%
blastn -query visch13_scaf.txt -out visch13_repeats_dust_plus.txt -db Vischeria_C74_genome_v1 -word_size 8 -seqidlist seqid.txt -num_threads 5 -strand plus
